# %%
import pandas as pd
import geopy.distance
# Out:
# /Users/dhkim/PycharmProjects/untitled/venv/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
star_bucks = pd.read_csv('../kakomap_crwal/data/starbucks/new_starbucks_review_groupby_200626.csv', sep='\t')
star_bucks = star_bucks.drop('Unnamed: 0', axis=1)
star_bucks = star_bucks.rename(columns={'loc_name':'지점명'})
star_bucks
# Out:
#                   지점명        address                          dates    scores  \
# 0     스타벅스 국립대구박물관DT점  황금동 69-3 64-5  2020-04-09 18:22:58.723404288  4.744681
# 1     스타벅스 대구영대병원역DT점      봉덕동 595-7  2020-04-08 01:06:58.604651264  4.744186
# 2       스타벅스 경주터미널DT점    사정동 488-7 8  2020-01-14 13:14:28.965517312  4.741379
# 3     스타벅스 대구수성네거리DT점   수성동4가 1021-8  2019-11-26 12:05:10.791366912  4.733813
# 4        스타벅스 광주매곡DT점         매곡동 15  2019-11-06 12:13:20.000000000  4.724537
# ..                ...            ...                            ...       ...
# 244     스타벅스 천안두정역DT점      두정동 71-13  2020-05-23 08:29:32.307692288  4.300000
# 245      스타벅스 전주평화DT점    평화동2가 300-1  2020-01-21 19:08:21.265822720  4.294304
# 246        스타벅스 속초DT점    조양동 1002-39  2020-01-11 05:39:13.846153728  4.293269
# 247   스타벅스 울산중리사거리DT점     삼산동 1545-5  2020-01-05 08:00:00.000000000  4.272109
# 248  스타벅스 리버사이드팔당DTR점     도곡리 504-15  2020-01-30 14:54:47.861271552  4.173410
#
# ...

# %%
file_path = './starbucksDT_location_info_20200707.csv'
starbucks_data = pd.read_csv(file_path, sep=',', index_col=0)
starbucks_data.to_csv(file_path, sep='\t')

# %%
starbucks_data
# Out:
#                 지점명   latitude   longitude  \
# 0      스타벅스 강동구청DT점  37.529139  127.123792
# 1      스타벅스 강동암사DT점  37.555040  127.130065
# 2      스타벅스 강릉송정DT점  37.771866  128.922926
# 3    스타벅스 경기광주송정DT점  37.424435  127.262841
# 4    스타벅스 경기광주신현DT점  37.359885  127.153039
# ..              ...        ...         ...
# 247     스타벅스 풍무역DT점  37.610333  126.737431
# 248    스타벅스 하남미사DT점  37.567550  127.189241
# 249  스타벅스 해운대달맞이DT점  35.161563  129.171237
# 250      스타벅스 화곡DT점  37.535035  126.863118
# 251    스타벅스 화성병점DT점  37.212610  127.038229
#
#                                                address
# 0                                              성내동 550
# 1                                           암사동 441-12
# 2    강원도 강릉시 경강로 2402    2020-03-31 18:56:50.526315776
# 3                                        송정동 12-12 1필지
# 4                                            신현리 701-5
# ..                                                 ...
# ...

# %%
intersect = set(starbucks_data['지점명']).intersection(set(star_bucks_add['지점명']))
set(starbucks_data['지점명']) - intersect
# Out:
# {'스타벅스 경주보문로DT점', '스타벅스 경주보문호수DT점', '스타벅스 공주동학사DT점'}

# %%
star_bucks_add = pd.read_csv('./20200707_starbuck_apt_info.csv', sep='\t', index_col=0)
star_bucks_add
# Out:
#                  지점명         아파트명                        주소     준공년월      세대  \
# 0    스타벅스 대구영대병원역DT점    영광비젼파크아파트         대구 남구 봉덕로11길 14-4      NaN     NaN
# 1       스타벅스 오산갈곶DT점   원동삼환나우빌아파트         경기 오산시 경기대로 99-15  1996.11  1168.0
# 2       스타벅스 대구칠성DT점     칠성동삼성아파트              대구 북구 호암로 40  1995.11   624.0
# 3       스타벅스 평택서정DT점        동산아파트         경기 평택시 특구로27번길 46  1989.10   520.0
# 4        스타벅스 동서대DT점  주례한일유앤아이아파트        부산 사상구 백양대로 372-15  2005.02   988.0
# ..               ...          ...                       ...      ...     ...
# 247     스타벅스 수원망포DT점   그대가프리미어아파트  경기 수원시 영통구 덕영대로1484번길 21  2010.08   602.0
# 248    스타벅스 풍무사거리DT점      풍무대림아파트         경기 김포시 풍무로93번길 30  2003.09   575.0
# 249   스타벅스 경주보문호수DT점          NaN                       NaN      NaN     NaN
# 250    스타벅스 공주동학사DT점          NaN                       NaN      NaN     NaN
# 251    스타벅스 경주보문로DT점          NaN                       NaN      NaN     NaN
#
# ...

# %%
new_dfs = []
for name in set(starbucks_data['지점명']) - intersect:
    df = {'지점명' : name, '아파트명' : pd.np.nan , '주소' : pd.np.nan , '준공년월' : pd.np.nan, '세대' : pd.np.nan, '가격' :pd.np.nan}
    new_dfs.append(df)
new_df = pd.DataFrame(new_dfs)
star_bucks_add_df = pd.concat([star_bucks_add, new_df]).reset_index(drop=True)
# Out:
# <ipython-input-22-7ca9718cf5a9>:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df = {'지점명' : name, '아파트명' : pd.np.nan , '주소' : pd.np.nan , '준공년월' : pd.np.nan, '세대' : pd.np.nan, '가격' :pd.np.nan}
#                  지점명         아파트명                        주소     준공년월      세대  \
# 0    스타벅스 대구영대병원역DT점    영광비젼파크아파트         대구 남구 봉덕로11길 14-4      NaN     NaN
# 1       스타벅스 오산갈곶DT점   원동삼환나우빌아파트         경기 오산시 경기대로 99-15  1996.11  1168.0
# 2       스타벅스 대구칠성DT점     칠성동삼성아파트              대구 북구 호암로 40  1995.11   624.0
# 3       스타벅스 평택서정DT점        동산아파트         경기 평택시 특구로27번길 46  1989.10   520.0
# 4        스타벅스 동서대DT점  주례한일유앤아이아파트        부산 사상구 백양대로 372-15  2005.02   988.0
# ..               ...          ...                       ...      ...     ...
# 247     스타벅스 수원망포DT점   그대가프리미어아파트  경기 수원시 영통구 덕영대로1484번길 21  2010.08   602.0
# ...

# %%
star_bucks_add_df
# Out:
#                  지점명         아파트명                        주소     준공년월      세대  \
# 0    스타벅스 대구영대병원역DT점    영광비젼파크아파트         대구 남구 봉덕로11길 14-4      NaN     NaN
# 1       스타벅스 오산갈곶DT점   원동삼환나우빌아파트         경기 오산시 경기대로 99-15  1996.11  1168.0
# 2       스타벅스 대구칠성DT점     칠성동삼성아파트              대구 북구 호암로 40  1995.11   624.0
# 3       스타벅스 평택서정DT점        동산아파트         경기 평택시 특구로27번길 46  1989.10   520.0
# 4        스타벅스 동서대DT점  주례한일유앤아이아파트        부산 사상구 백양대로 372-15  2005.02   988.0
# ..               ...          ...                       ...      ...     ...
# 247     스타벅스 수원망포DT점   그대가프리미어아파트  경기 수원시 영통구 덕영대로1484번길 21  2010.08   602.0
# 248    스타벅스 풍무사거리DT점      풍무대림아파트         경기 김포시 풍무로93번길 30  2003.09   575.0
# 249   스타벅스 경주보문호수DT점          NaN                       NaN      NaN     NaN
# 250    스타벅스 공주동학사DT점          NaN                       NaN      NaN     NaN
# 251    스타벅스 경주보문로DT점          NaN                       NaN      NaN     NaN
#
# ...

# %%
star_bucks_add_df['s_latitude'] = ''
star_bucks_add_df['s_longitude'] = ''

for idx, row in starbucks_data.iterrows():
    star_bucks_add_df.loc[star_bucks_add_df['지점명']==row['지점명'], 's_latitude'] = row['latitude']
    star_bucks_add_df.loc[star_bucks_add_df['지점명']==row['지점명'], 's_longitude'] = row['longitude']
star_bucks_add_df
# Out:
#                  지점명         아파트명                        주소     준공년월      세대  \
# 0    스타벅스 대구영대병원역DT점    영광비젼파크아파트         대구 남구 봉덕로11길 14-4      NaN     NaN
# 1       스타벅스 오산갈곶DT점   원동삼환나우빌아파트         경기 오산시 경기대로 99-15  1996.11  1168.0
# 2       스타벅스 대구칠성DT점     칠성동삼성아파트              대구 북구 호암로 40  1995.11   624.0
# 3       스타벅스 평택서정DT점        동산아파트         경기 평택시 특구로27번길 46  1989.10   520.0
# 4        스타벅스 동서대DT점  주례한일유앤아이아파트        부산 사상구 백양대로 372-15  2005.02   988.0
# ..               ...          ...                       ...      ...     ...
# 247     스타벅스 수원망포DT점   그대가프리미어아파트  경기 수원시 영통구 덕영대로1484번길 21  2010.08   602.0
# 248    스타벅스 풍무사거리DT점      풍무대림아파트         경기 김포시 풍무로93번길 30  2003.09   575.0
# 249   스타벅스 경주보문호수DT점          NaN                       NaN      NaN     NaN
# 250    스타벅스 공주동학사DT점          NaN                       NaN      NaN     NaN
# 251    스타벅스 경주보문로DT점          NaN                       NaN      NaN     NaN
#
# ...

# %%
def get_distance(row):
    try:
        return geopy.distance.vincenty((row.latitude,row.longitude), (row.s_latitude,row.s_longitude)).km
    except:
        return 9999
star_bucks_add_df['distance'] = star_bucks_add_df.apply(lambda row:get_distance(row), axis=1)
star_bucks_add_df
# Out:
# <ipython-input-63-2c060df01a47>:3: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   return geopy.distance.vincenty((row.latitude,row.longitude), (row.s_latitude,row.s_longitude)).km
#                  지점명         아파트명                        주소     준공년월      세대  \
# 0    스타벅스 대구영대병원역DT점    영광비젼파크아파트         대구 남구 봉덕로11길 14-4      NaN     NaN
# 1       스타벅스 오산갈곶DT점   원동삼환나우빌아파트         경기 오산시 경기대로 99-15  1996.11  1168.0
# 2       스타벅스 대구칠성DT점     칠성동삼성아파트              대구 북구 호암로 40  1995.11   624.0
# 3       스타벅스 평택서정DT점        동산아파트         경기 평택시 특구로27번길 46  1989.10   520.0
# 4        스타벅스 동서대DT점  주례한일유앤아이아파트        부산 사상구 백양대로 372-15  2005.02   988.0
# ..               ...          ...                       ...      ...     ...
# 247     스타벅스 수원망포DT점   그대가프리미어아파트  경기 수원시 영통구 덕영대로1484번길 21  2010.08   602.0
# ...

# %%
star_bucks_add_df.sort_values('distance', ascending=False)[:10]
# Out:
#                 지점명               아파트명                             주소  \
# 251   스타벅스 경주보문로DT점                NaN                            NaN
# 249  스타벅스 경주보문호수DT점                NaN                            NaN
# 250   스타벅스 공주동학사DT점                NaN                            NaN
# 157     스타벅스 서귀포DT점  제주강정유승한내들퍼스트오션아파트  제주 서귀포시 대청로 34 제주강정유승한내들퍼스트오션
# 71     스타벅스 광주선운DT점       선운이지더원2단지아파트                광주 광산구 선운중앙로 43
# 165      스타벅스 원당DT점      어울림마을동신7단지아파트             경기 고양시 덕양구 호국로 754
# 161      스타벅스 신림DT점           라이프미성아파트                서울 관악구 조원로2길 13
# 136    스타벅스 광주효천DT점      광주효천중흥S클래스아파트               광주 남구 효우로 332-11
# 174    스타벅스 구미상모DT점      구미상모한신휴플러스아파트               경북 구미시 박정희로 76-1
# 162    스타벅스 포항장성DT점    포항장성두산위브더제니스아파트           경북 포항시 북구 새천년대로 1235
#
#         준공년월      세대                                                가격  \
# 251      NaN     NaN                                               NaN
# ...

# %%
import numpy as np

# %%
type(star_bucks_add_df.loc[0,'가격'])
# Out:
# float

# %%
def price_process(x, flag):
    if not isinstance(x, float):
        split_x = x.split('\n')
        if flag=='매매가':
            return split_x[0].replace(flag,'').replace(',','').replace('(만원)','').split('-')
        else:
            if len(split_x) > 1:
                return split_x[1:][0].replace(flag,'').replace(',','').replace('(만원)','').split('-')
            else:
                return np.nan
    else:
        return x
star_bucks_add_df['전세가'] = star_bucks_add_df['가격'].map(lambda x:price_process(x,'전세가'))
star_bucks_add_df['매매가'] = star_bucks_add_df['가격'].map(lambda x:price_process(x,'매매가'))

# %%
# Out:
# 0                    NaN
# 1      [12000 ,  15000 ]
# 2      [17000 ,  30000 ]
# 3        [6000 ,  8500 ]
# 4      [17000 ,  32000 ]
#              ...
# 247    [34000 ,  55000 ]
# 248    [18500 ,  21500 ]
# 249                  NaN
# 250                  NaN
# 251                  NaN
# Name: 전세가, Length: 252, dtype: object

# %%
' 14500 '.strip()
# Out:
# '14500'

# %%
def custom_map(x):
    if not isinstance(x, float):
        if isinstance(x, list):
            for string in x:
                if ('전세' in string) or ('월세') in string or ('매매') in string:
                    return True
                else:
                    return False
            if ('전세' in string) or ('월세') in string or ('매매') in string:
                return True
            else:
                return False
    else:
        return False
        
except_price = star_bucks_add_df[star_bucks_add_df['매매가'].map(lambda x:custom_map(x))]
except_price
# Out:
#                 지점명           아파트명                           주소     준공년월  \
# 19     스타벅스 천안성정DT점        계룡리슈빌DS          충남 천안시 서북구 성정두정로 19  2016.09
# 27     스타벅스 경산중방DT점        초원맨션아파트          경북 경산시 경안로48길 11-12  1989.05
# 38     스타벅스 충주호암DT점  충주호암지구우미린에듀시티  충북 충주시 호암수청1로 13 우미린에듀시티아파트  2019.08
# 43   스타벅스 해운대달맞이DT점       해운대엘시티더샵              부산 해운대구 달맞이길 30  2019.11
# 54   스타벅스 전주덕진광장DT점       거성대학촌아파트           전북 전주시 덕진구 명륜4길 16  1983.08
# 65     스타벅스 충남보령DT점   금성백조예미지2차아파트             충남 보령시 명천동 산38-9  2019.11
# 78     스타벅스 대구두류DT점          세신아파트            대구 서구 달구벌대로361길 9  1981.04
# 90     스타벅스 구미시청DT점        상산에이스타운             경북 구미시 신시로14길 10  2002.09
# 135    스타벅스 동대구로DT점   동대구유성푸르나임아파트              대구 동구 동부로22길 48  2014.11
# 138      스타벅스 연희DT점          연화아파트           서울 서대문구 연희로25길 101  1975.12
# 227    스타벅스 제주외도DT점          가온체리티                제주 제주시 우정로 37  2005.12
# 241  스타벅스 수원경수인계DT점        해피포트아파트   경기 수원시 팔달구 경수대로519번길 12-13  2004.01
#
# ...

# %%
for idx, row in except_price.iterrows():
    print(idx, row[11])
    if '매매' in row['매매가'][0]:
        maemae = row['매매가'][0].split(' ')[1]

        star_bucks_add_df.loc[idx, '매매가상한'] = int(maemae + '00000000')
        star_bucks_add_df.loc[idx, '매매가하한'] = int(maemae + '00000000')
    else:
        star_bucks_add_df.loc[idx, '매매가상한'] = np.nan
        star_bucks_add_df.loc[idx, '매매가하한'] = np.nan
# Out:
# 19 ['매매 3 전세 2 월세 5']
# 27 ['매매 7']
# 38 ['매매 2 전세 6']
# 43 ['매매 329 전세 229 월세 403']
# 54 ['매매 1 전세 1']
# 65 ['매매 5 월세 1']
# 78 ['매매 1 월세 7']
# 90 ['매매 1']
# 135 ['매매 36 전세 6 월세 31']
# 138 ['매매 8 전세 1']
# 227 ['월세 1']
# 241 ['매매 6']

# %%
star_bucks_add_df[star_bucks_add_df['전세가'].map(lambda x:custom_map(x))]
# Out:
# Empty DataFrame
# Columns: [지점명, 아파트명, 주소, 준공년월, 세대, 가격, latitude, longitude, s_latitude, s_longitude, distance, 매매가, 전세가]
# Index: []

# %%
def cus_map(x, index):
    try:
        return int(x[index].strip() +'0000') if not isinstance(x, float) else x
    except:
        return x

star_bucks_add_df['매매가하한'] = star_bucks_add_df['매매가'].map(lambda x:cus_map(x, 0))
star_bucks_add_df['매매가상한'] = star_bucks_add_df['매매가'].map(lambda x:cus_map(x, 1))

# %%
star_bucks_add_df_apt_final = star_bucks_add_df[['지점명','아파트명','준공년월','세대','distance','매매가하한','매매가상한']]

# %%
star_bucks_add_df_apt_final.to_csv('20200707_starbucks_apt_final_dist_price.csv', sep='\t')

# %%
star_bucks_add_df[star_bucks_add_df['전세가'].str.len()>1]
# Out:
# Empty DataFrame
# Columns: [지점명, 아파트명, 주소, 준공년월, 세대, 가격, latitude, longitude, s_latitude, s_longitude, distance, 매매가, 전세가]
# Index: []

# %%
star_bucks_add_df.to_csv('./20200707_starbuck_apt_info_dist.csv', sep='\t')

# %%
for idx, row in missing_coord.iterrows():
    star_bucks_add_df.loc[star_bucks_add_df['주소']==row['주소'], 'latitude'] = row['latitude']
    star_bucks_add_df.loc[star_bucks_add_df['주소']==row['주소'], 'longitude'] = row['longitude']
star_bucks_add_df
# Out:
#                  지점명         아파트명                        주소     준공년월      세대  \
# 0    스타벅스 대구영대병원역DT점    영광비젼파크아파트         대구 남구 봉덕로11길 14-4      NaN     NaN
# 1       스타벅스 오산갈곶DT점   원동삼환나우빌아파트         경기 오산시 경기대로 99-15  1996.11  1168.0
# 2       스타벅스 대구칠성DT점     칠성동삼성아파트              대구 북구 호암로 40  1995.11   624.0
# 3       스타벅스 평택서정DT점        동산아파트         경기 평택시 특구로27번길 46  1989.10   520.0
# 4        스타벅스 동서대DT점  주례한일유앤아이아파트        부산 사상구 백양대로 372-15  2005.02   988.0
# ..               ...          ...                       ...      ...     ...
# 247     스타벅스 수원망포DT점   그대가프리미어아파트  경기 수원시 영통구 덕영대로1484번길 21  2010.08   602.0
# 248    스타벅스 풍무사거리DT점      풍무대림아파트         경기 김포시 풍무로93번길 30  2003.09   575.0
# 249   스타벅스 경주보문호수DT점          NaN                       NaN      NaN     NaN
# 250    스타벅스 공주동학사DT점          NaN                       NaN      NaN     NaN
# 251    스타벅스 경주보문로DT점          NaN                       NaN      NaN     NaN
#
# ...

# %%
import requests

# %%
def find_lat_lng(location):
    # 요청 주소(구글맵)

    # Production(실제 서비스) 환경 - https 요청이 필수이고, API Key 발급(사용설정) 및 과금 설정이 반드시 필요합니다.
    URL = 'https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBWgPcQF1nWKXIwGLPJVZA4-QYLw5GdVVM' \
          '&sensor=false&language=ko&address={}'.format(location)
    try:
        # URL로 보낸 Requst의 Response를 response 변수에 할당
        response = requests.get(URL)

        # JSON 파싱
        data = response.json()

        # lat, lon 추출
        lat = data['results'][0]['geometry']['location']['lat']
        lng = data['results'][0]['geometry']['location']['lng']
    except Exception as e:
        print(f'{e} : {location} failed to find coordinates')
        # time.sleep(1)
        # lat, lng = find_lat_lng(location)
        lat, lng = 0, 0
    return lat, lng

# %%
locs = []
for loc in mystery:
    loc_ = find_lat_lng(loc)
    print(loc_)
    loc_dict = {'주소' : loc,
                'latitude':loc_[0],
                'longitude':loc_[1]}
    locs.append(loc_dict)
# Out:
# (35.8455285, 128.596193)
# (37.13286799999999, 127.0708067)
# (35.173195, 129.106528)
# (35.8902141, 128.5904713)
# (36.8323797, 127.1415812)
# (35.319206, 129.0264601)
# (35.8380516, 128.6108302)
# (35.8199118, 128.5333122)
# (37.209423, 127.0549932)
# (37.538185, 126.863257)
# (35.1737511, 126.8105744)
# (37.3982139, 127.2715036)
# (37.69379, 126.7624419)
# (36.8015412, 127.128244)
# (35.6428989, 129.3506784)
# (33.2514324, 126.5034108)
# (34.8220309, 126.4174952)
# (37.645713, 127.2376928)
# (37.2990376, 127.1115909)
# (35.8532819, 128.6353823)
# (37.85324019999999, 127.7394869)
# (37.7928979, 127.0743041)
# (35.1730617, 126.8198934)
# (37.242286, 127.214716)
# (37.2707716, 127.0261542)
# (33.2553905, 126.4295446)
# (35.8496807, 128.6088181)
# (36.1402776, 128.3147894)
# (33.791638, -84.389488)
# (33.791638, -84.389488)
# (33.791638, -84.389488)

# %%
missing_coord = pd.DataFrame(locs)

# %%
star_bucks_add_df.sort_values('distance').reset_index(drop=True)[-20:]
# Out:
#                  지점명               아파트명                             주소  \
# 232   스타벅스 천안서부대로DT점            광명장미아파트             충남 천안시 서북구 미라2길 19
# 233     스타벅스 천안성정DT점            계룡리슈빌DS            충남 천안시 서북구 성정두정로 19
# 234    스타벅스 목포터미널DT점    목포상동호반리젠시빌아파트입구                      전남 목포시 상동
# 235    스타벅스 공주동학사DT점                NaN                            NaN
# 236     스타벅스 광주산정DT점      영천마을주공10단지아파트             광주 광산구 사암로340번길 30
# 237     스타벅스 광주운남DT점            운남삼성아파트            광주 광산구 임방울대로 142-12
# 238      스타벅스 서귀포DT점  제주강정유승한내들퍼스트오션아파트  제주 서귀포시 대청로 34 제주강정유승한내들퍼스트오션
# 239     스타벅스 제주중문DT점       제주중문남해오네뜨오션힐            제주 서귀포시 중문상로82번길 15
# 240     스타벅스 구미도량DT점        구미도량지구현진에버빌                  경북 구미시 도봉로 10
# 241     스타벅스 대구상인DT점        상인KCC스위첸아파트               대구 달서구 월배로39길 26
# 242     스타벅스 대구침산DT점   오페라삼정그린코아더베스트아파트                  대구 북구 침산로 100
# 243  스타벅스 대구영대병원역DT점          영광비젼파크아파트              대구 남구 봉덕로11길 14-4
# ...

# %%
before_apt_info = pd.read_csv('./starbucks_apt_info_20200703.csv', sep='\t', index_col=0)
before_apt_info
# Out:
#                 지점명                 아파트명                    주소     준공년월  \
# 0      스타벅스 강동구청DT점            성안마을청구아파트      서울 강동구 풍성로 114-1  2002.07
# 1      스타벅스 강동암사DT점             삼성광나루아파트       서울 강동구 상암로3길 77  2002.11
# 2      스타벅스 강릉송정DT점           포남동주공1차아파트       강원 강릉시 보래미상길 65  1981.10
# 3    스타벅스 경기광주송정DT점         금강펜테리움2단지아파트       경기 광주시 경안천로 145  2010.06
# 4    스타벅스 경기광주신현DT점        e편한세상태재1단지아파트  경기 광주시 오포읍 태재로 20-15  2018.07
# ..              ...                  ...                   ...      ...
# 244     스타벅스 풍무역DT점  김포풍무꿈에그린유로메트로1단지아파트     경기 김포시 풍무로68번길 39  2014.05
# 245    스타벅스 하남미사DT점         미사강변센트럴자이아파트      경기 하남시 미사강변대로 95  2017.02
# 246  스타벅스 해운대달맞이DT점             해운대엘시티더샵       부산 해운대구 달맞이길 30  2019.11
# 247      스타벅스 화곡DT점          목동세종그랑시아아파트   서울 양천구 목동중앙남로3가길 59  2003.05
# 248    스타벅스 화성병점DT점      다람마을월드메르디앙2차아파트        경기 화성시 병점4로 37  2005.11
#
#          세대  아파트유무  s_latitude  s_longitude   latitude   longitude    distance
# ...

# %%
star_bucks_add_df['latitude'] = ''
star_bucks_add_df['longitude'] = ''

for idx, row in before_apt_info.iterrows():
    star_bucks_add_df.loc[star_bucks_add_df['아파트명']==row['아파트명'], 'latitude'] = row['latitude']
    star_bucks_add_df.loc[star_bucks_add_df['아파트명']==row['아파트명'], 'longitude'] = row['longitude']
star_bucks_add_df
# Out:
#                  지점명         아파트명                        주소     준공년월      세대  \
# 0    스타벅스 대구영대병원역DT점    영광비젼파크아파트         대구 남구 봉덕로11길 14-4      NaN     NaN
# 1       스타벅스 오산갈곶DT점   원동삼환나우빌아파트         경기 오산시 경기대로 99-15  1996.11  1168.0
# 2       스타벅스 대구칠성DT점     칠성동삼성아파트              대구 북구 호암로 40  1995.11   624.0
# 3       스타벅스 평택서정DT점        동산아파트         경기 평택시 특구로27번길 46  1989.10   520.0
# 4        스타벅스 동서대DT점  주례한일유앤아이아파트        부산 사상구 백양대로 372-15  2005.02   988.0
# ..               ...          ...                       ...      ...     ...
# 247     스타벅스 수원망포DT점   그대가프리미어아파트  경기 수원시 영통구 덕영대로1484번길 21  2010.08   602.0
# 248    스타벅스 풍무사거리DT점      풍무대림아파트         경기 김포시 풍무로93번길 30  2003.09   575.0
# 249   스타벅스 경주보문호수DT점          NaN                       NaN      NaN     NaN
# 250    스타벅스 공주동학사DT점          NaN                       NaN      NaN     NaN
# 251    스타벅스 경주보문로DT점          NaN                       NaN      NaN     NaN
#
# ...

# %%
star_bucks_add_df

# %%
def get_distance(row):
    try:
        return geopy.distance.vincenty((row.latitude_x,row.longitude_x), (row.latitude_y,row.longitude_y)).km
    except:
        return 9999
merged_df['distance'] = merged_df.apply(lambda row:get_distance(row), axis=1)
merged_df

# %%
star_bucks[star_bucks['지점명']=='스타벅스 대구중동DT점']
# Out:
#               지점명            address                          dates    scores  \
# 181  스타벅스 대구중동DT점  대전광역시 동구 중동 316-3  2020-01-19 11:18:20.826446336  4.479339
#
#      reviews   latitude   longitude
# 181      113  36.331921  127.426931

# %%
merged_df = pd.merge(x, star_bucks, 'right', on='지점명')

# %%
x = pd.read_csv('/Users/dhkim/PycharmProjects/kakomap_crwal/data/2020-07-03_11_58_apt_review.csv', sep='\t')
x = x.drop('Unnamed: 0', axis=1)
x.to_csv('/Users/dhkim/PycharmProjects/kakomap_crwal/data/2020-07-03_11_58_apt_review.csv', sep='\t')
x
# Out:
#                   지점명             아파트명                   주소     준공년월      세대  \
# 0     스타벅스 국립대구박물관DT점  황금동캐슬골드파크1단지아파트       대구 수성구 청수로 213  2006.07  1059.0
# 1     스타벅스 대구영대병원역DT점     봉덕동우인그레이스아파트       대구 남구 중앙대로 114  2016.01    16.0
# 2       스타벅스 경주터미널DT점          동부이끌림6차   경북 경주시 금성로247번길 15  2014.06    50.0
# 3     스타벅스 대구수성네거리DT점           롬바드아파트       대구 수성구 들안로 325  2011.07   108.0
# 4        스타벅스 광주매곡DT점          용봉주공아파트         광주 북구 매곡로 20      NaN     NaN
# ..                ...              ...                  ...      ...     ...
# 241     스타벅스 천안두정역DT점        두정대우1차아파트   충남 천안시 서북구 봉정로 365  1996.12  1038.0
# 242      스타벅스 전주평화DT점         평화동우미아파트  전북 전주시 완산구 모악로 4685  1996.06   603.0
# 243        스타벅스 속초DT점         부영5단지아파트   강원 속초시 청대로204번길 40  1995.07  1030.0
# 244   스타벅스 울산중리사거리DT점        평창현대3차아파트   울산 남구 삼산중로128번길 21  1995.10   782.0
# 245  스타벅스 리버사이드팔당DTR점          한강우성아파트  경기 남양주시 와부읍 덕소로 270  1998.07  1488.0
#
#       latitude   longitude
# ...

# %%
for loc in x.지점명.values:
    if loc in star_bucks.지점명.values:
        
#         print(loc)
        continue
    else:
        print(loc)

# %%
x['아파트유무'] = x['지점명'].map(lambda x:True if x in star_bucks.지점명.values else False)
x
# Out:
#                   지점명             아파트명                   주소     준공년월      세대  \
# 0     스타벅스 국립대구박물관DT점  황금동캐슬골드파크1단지아파트       대구 수성구 청수로 213  2006.07  1059.0
# 1     스타벅스 대구영대병원역DT점     봉덕동우인그레이스아파트       대구 남구 중앙대로 114  2016.01    16.0
# 2       스타벅스 경주터미널DT점          동부이끌림6차   경북 경주시 금성로247번길 15  2014.06    50.0
# 3     스타벅스 대구수성네거리DT점           롬바드아파트       대구 수성구 들안로 325  2011.07   108.0
# 4        스타벅스 광주매곡DT점          용봉주공아파트         광주 북구 매곡로 20      NaN     NaN
# ..                ...              ...                  ...      ...     ...
# 241     스타벅스 천안두정역DT점        두정대우1차아파트   충남 천안시 서북구 봉정로 365  1996.12  1038.0
# 242      스타벅스 전주평화DT점         평화동우미아파트  전북 전주시 완산구 모악로 4685  1996.06   603.0
# 243        스타벅스 속초DT점         부영5단지아파트   강원 속초시 청대로204번길 40  1995.07  1030.0
# 244   스타벅스 울산중리사거리DT점        평창현대3차아파트   울산 남구 삼산중로128번길 21  1995.10   782.0
# 245  스타벅스 리버사이드팔당DTR점          한강우성아파트  경기 남양주시 와부읍 덕소로 270  1998.07  1488.0
#
#       latitude   longitude  아파트유무
# ...

# %%
idx = x.shape[0]
for loc in list(set(star_bucks.지점명.values) - set(x.지점명.values)):
    x.loc[idx, '지점명'] = loc
    x.loc[idx, '아파트명'] = ''
    x.loc[idx, '주소'] = ''
    x.loc[idx, '준공년월'] = ''
    x.loc[idx, '아파트유무'] = False
    idx += 1
x
# Out:
#                   지점명             아파트명                   주소     준공년월      세대  \
# 0     스타벅스 국립대구박물관DT점  황금동캐슬골드파크1단지아파트       대구 수성구 청수로 213  2006.07  1059.0
# 1     스타벅스 대구영대병원역DT점     봉덕동우인그레이스아파트       대구 남구 중앙대로 114  2016.01    16.0
# 2       스타벅스 경주터미널DT점          동부이끌림6차   경북 경주시 금성로247번길 15  2014.06    50.0
# 3     스타벅스 대구수성네거리DT점           롬바드아파트       대구 수성구 들안로 325  2011.07   108.0
# 4        스타벅스 광주매곡DT점          용봉주공아파트         광주 북구 매곡로 20      NaN     NaN
# ..                ...              ...                  ...      ...     ...
# 244   스타벅스 울산중리사거리DT점        평창현대3차아파트   울산 남구 삼산중로128번길 21   1995.1   782.0
# 245  스타벅스 리버사이드팔당DTR점          한강우성아파트  경기 남양주시 와부읍 덕소로 270  1998.07  1488.0
# 246     스타벅스 공주동학사DT점                                                    NaN
# 247    스타벅스 경주보문호수DT점                                                    NaN
# 248     스타벅스 경주보문로DT점                                                    NaN
#
#       latitude   longitude  아파트유무
# ...

# %%
x = x.sort_values('지점명')
star_bucks = star_bucks.sort_values('지점명')
x
star_bucks
# Out:
#                 지점명                                            address  \
# 166    스타벅스 강동구청DT점                                            성내동 550
# 229    스타벅스 강동암사DT점                                         암사동 441-12
# 162    스타벅스 강릉송정DT점  강원도 강릉시 경강로 2402    2020-03-31 18:56:50.526315776
# 184  스타벅스 경기광주송정DT점                                      송정동 12-12 1필지
# 237  스타벅스 경기광주신현DT점                                          신현리 701-5
# ..              ...                                                ...
# 210     스타벅스 풍무역DT점                                          풍무동 326-4
# 243    스타벅스 하남미사DT점                                         망월동 1066-3
# 54   스타벅스 해운대달맞이DT점                                            중동 1779
# 88       스타벅스 화곡DT점                                         화곡동 772-67
# 182    스타벅스 화성병점DT점                                          진안동 873-4
#
#                              dates     scores  reviews   latitude   longitude
# ...

# %%
x['s_latitude'] = ''
x['s_longitude'] = ''

# %%
for j in range(x.shape[0]):
    for i in range(star_bucks.shape[0]):
        if x.loc[j,'지점명']==star_bucks.loc[i,'지점명']:
            x['s_latitude'] = star_bucks.loc[i,'latitude']
            x['s_longitude'] = star_bucks.loc[i,'longitude']
x
# Out:
#                 지점명                 아파트명                    주소     준공년월  \
# 163    스타벅스 강동구청DT점            성안마을청구아파트      서울 강동구 풍성로 114-1  2002.07
# 226    스타벅스 강동암사DT점             삼성광나루아파트       서울 강동구 상암로3길 77  2002.11
# 159    스타벅스 강릉송정DT점           포남동주공1차아파트       강원 강릉시 보래미상길 65   1981.1
# 181  스타벅스 경기광주송정DT점         금강펜테리움2단지아파트       경기 광주시 경안천로 145  2010.06
# 234  스타벅스 경기광주신현DT점        e편한세상태재1단지아파트  경기 광주시 오포읍 태재로 20-15  2018.07
# ..              ...                  ...                   ...      ...
# 207     스타벅스 풍무역DT점  김포풍무꿈에그린유로메트로1단지아파트     경기 김포시 풍무로68번길 39  2014.05
# 240    스타벅스 하남미사DT점         미사강변센트럴자이아파트      경기 하남시 미사강변대로 95  2017.02
# 53   스타벅스 해운대달맞이DT점             해운대엘시티더샵       부산 해운대구 달맞이길 30  2019.11
# 87       스타벅스 화곡DT점          목동세종그랑시아아파트   서울 양천구 목동중앙남로3가길 59  2003.05
# 179    스타벅스 화성병점DT점      다람마을월드메르디앙2차아파트        경기 화성시 병점4로 37  2005.11
#
#          세대   latitude   longitude 아파트유무  s_latitude  s_longitude
# ...

# %%
x = x.reset_index(drop=True)
x
# Out:
#                 지점명                 아파트명                    주소     준공년월  \
# 0      스타벅스 강동구청DT점            성안마을청구아파트      서울 강동구 풍성로 114-1  2002.07
# 1      스타벅스 강동암사DT점             삼성광나루아파트       서울 강동구 상암로3길 77  2002.11
# 2      스타벅스 강릉송정DT점           포남동주공1차아파트       강원 강릉시 보래미상길 65   1981.1
# 3    스타벅스 경기광주송정DT점         금강펜테리움2단지아파트       경기 광주시 경안천로 145  2010.06
# 4    스타벅스 경기광주신현DT점        e편한세상태재1단지아파트  경기 광주시 오포읍 태재로 20-15  2018.07
# ..              ...                  ...                   ...      ...
# 244     스타벅스 풍무역DT점  김포풍무꿈에그린유로메트로1단지아파트     경기 김포시 풍무로68번길 39  2014.05
# 245    스타벅스 하남미사DT점         미사강변센트럴자이아파트      경기 하남시 미사강변대로 95  2017.02
# 246  스타벅스 해운대달맞이DT점             해운대엘시티더샵       부산 해운대구 달맞이길 30  2019.11
# 247      스타벅스 화곡DT점          목동세종그랑시아아파트   서울 양천구 목동중앙남로3가길 59  2003.05
# 248    스타벅스 화성병점DT점      다람마을월드메르디앙2차아파트        경기 화성시 병점4로 37  2005.11
#
#          세대   latitude   longitude 아파트유무  s_latitude  s_longitude
# ...

# %%
x.to_csv('starbucks_btw_apt_info.csv', sep='\t')

# %%
starbucks.to_csv('starbucks_location_info.csv', sep='\t')

# %%
for e in edit:
    name = e.split(' ')[1]
    starbucks[starbucks['지점명'].map(lambda x:name in x)] = e

# %%
starbucks[starbucks['지점명'].map(lambda x:'울산MBC' in x)] = e

# %%
starbucks[starbucks['지점명'].map(lambda x:'울산' in x)]
# Out:
#                  지점명 latitude longitude  SORT
# 0       스타벅스 울산신정DT점  35.5442   129.325  스타벅스
# 65   스타벅스 울산중리사거리DT점  35.5439   129.339  스타벅스
# 66     스타벅스 울산남구청DT점  35.5442   129.325  스타벅스
# 78    스타벅스 울산정자비치DT점  35.6288   129.441  스타벅스
# 89   스타벅스 울산시청사거리DT점  35.5372   129.313  스타벅스
# 129    스타벅스 울산북구청DT점  35.5834   129.359  스타벅스
# 147  스타벅스 울산도산사거리DT점   35.531    129.33  스타벅스
# 185     스타벅스 울산호계DT점  35.5834   129.359  스타벅스

# %%
 x[x['아파트유무']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-243-7534771d685c> in <module>
# ----> 1 x[~x['아파트유무']]
#
# ~/PycharmProjects/untitled/venv/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/PycharmProjects/untitled/venv/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ...

# %%
edit
# Out:
# array(['스타벅스 울산MBC DT점', '스타벅스 남양산IC DT점', '스타벅스 신월IC DT점',
#        '스타벅스 대구성서IC DT점', '스타벅스 수원KBS DT점', '스타벅스 대전IC DT점',
#        '스타벅스 천안IC DT점', '스타벅스 수원IC DT점', '스타벅스 오산IC DT점',
#        '스타벅스 북수원IC DT점', '스타벅스 북오산IC DT점', '스타벅스 리버사이드팔당DTR점'],
#       dtype=object)

# %%
starbucks = starbucks.rename(columns={'star_name':'지점명'})
# Out:
#                지점명   latitude   longitude  SORT
# 0      스타벅스 울산신정DT  35.544170  129.324735  스타벅스
# 1     스타벅스 경주보문로DT  35.853218  129.268695  스타벅스
# 2       스타벅스 동수원DT  37.278015  127.033828  스타벅스
# 3       스타벅스 서귀포DT  33.249525  126.506710  스타벅스
# 4     스타벅스 구미금오산DT  36.122231  128.323599  스타벅스
# ..             ...        ...         ...   ...
# 249   스타벅스 목포터미널DT  34.810017  126.417053  스타벅스
# 250    스타벅스 마산회원DT  35.220657  128.574434  스타벅스
# 251     스타벅스 평촌역DT  37.396431  126.969419  스타벅스
# 252    스타벅스 시흥대야DT  37.443912  126.790755  스타벅스
# 253  스타벅스 수원경수인계DT  37.267928  127.027944  스타벅스
#
# [254 rows x 4 columns]

# %%
starbucks = pd.read_csv('starbucks_location_info.csv', sep='\t')
starbucks = starbucks.drop('Unnamed: 0', axis=1)
starbucks
# Out:
#          star_name   latitude   longitude  SORT
# 0      스타벅스 울산신정DT  35.544170  129.324735  스타벅스
# 1     스타벅스 경주보문로DT  35.853218  129.268695  스타벅스
# 2       스타벅스 동수원DT  37.278015  127.033828  스타벅스
# 3       스타벅스 서귀포DT  33.249525  126.506710  스타벅스
# 4     스타벅스 구미금오산DT  36.122231  128.323599  스타벅스
# ..             ...        ...         ...   ...
# 249   스타벅스 목포터미널DT  34.810017  126.417053  스타벅스
# 250    스타벅스 마산회원DT  35.220657  128.574434  스타벅스
# 251     스타벅스 평촌역DT  37.396431  126.969419  스타벅스
# 252    스타벅스 시흥대야DT  37.443912  126.790755  스타벅스
# 253  스타벅스 수원경수인계DT  37.267928  127.027944  스타벅스
#
# [254 rows x 4 columns]

# %%
x['address2'] = x['address'].map(lambda x:x.split('\n')[0] if isinstance(x, str) else x)

# %%
x = x[x['address2'].map(lambda x:False if isinstance(x, float) else True)]

# %%
x.reset_index(drop=True, inplace=True)
x
# Out:
#        loc_name                                 address  num_review  \
# 0       을왕리해수욕장                     인천광역시 중구 을왕로13번길 15      455237
# 1       장경리해수욕장  인천광역시 옹진군 영흥면 영흥로757번길 6\n032-899-2114       42274
# 2       하나개해수욕장                     인천광역시 중구 무의동 산189번지       69251
# 3        왕산해수욕장                            인천광역시 중구 을왕동       92943
# 4          수기해변            인천광역시 옹진군 북도면 시도로86번길 291-48       34234
# ...         ...                                     ...         ...
# 9520  강촌 출렁다리공원     강원도 춘천시 남산면 강촌리 671-5\n033-250-3075         930
# 9521    강촌 번지점프       강원도 춘천시 남산면 강촌로 256\n033-262-2228         522
# 9522  천등산전통발효식품     충청북도 충주시 산척면 세고개로 277\n043-847-8074         671
# 9523       살둔계곡   강원도 홍천군 내면 살둔길 3\n홍천문화관광 011-430-2471        1393
# 9524        소금산   강원도 원주시 지정면 간현리\n원주 문화관광 033-737-5133        1374
#
#                           address2
# 0              인천광역시 중구 을왕로13번길 15
# 1         인천광역시 옹진군 영흥면 영흥로757번길 6
# 2              인천광역시 중구 무의동 산189번지
# ...

# %%
result = pd.read_csv('../company_list/starbucks_btw_apt_info.csv', sep='\t' )
result = result.drop(result.columns[0], axis=1)
result
# Out:
#                 지점명                 아파트명                    주소     준공년월  \
# 0      스타벅스 강동구청DT점            성안마을청구아파트      서울 강동구 풍성로 114-1  2002.07
# 1      스타벅스 강동암사DT점             삼성광나루아파트       서울 강동구 상암로3길 77  2002.11
# 2      스타벅스 강릉송정DT점           포남동주공1차아파트       강원 강릉시 보래미상길 65  1981.10
# 3    스타벅스 경기광주송정DT점         금강펜테리움2단지아파트       경기 광주시 경안천로 145  2010.06
# 4    스타벅스 경기광주신현DT점        e편한세상태재1단지아파트  경기 광주시 오포읍 태재로 20-15  2018.07
# ..              ...                  ...                   ...      ...
# 244     스타벅스 풍무역DT점  김포풍무꿈에그린유로메트로1단지아파트     경기 김포시 풍무로68번길 39  2014.05
# 245    스타벅스 하남미사DT점         미사강변센트럴자이아파트      경기 하남시 미사강변대로 95  2017.02
# 246  스타벅스 해운대달맞이DT점             해운대엘시티더샵       부산 해운대구 달맞이길 30  2019.11
# 247      스타벅스 화곡DT점          목동세종그랑시아아파트   서울 양천구 목동중앙남로3가길 59  2003.05
# 248    스타벅스 화성병점DT점      다람마을월드메르디앙2차아파트        경기 화성시 병점4로 37  2005.11
#
#          세대  아파트유무  s_latitude  s_longitude   latitude   longitude
# ...

# %%
star_df = result[['지점명', 's_latitude', 's_longitude']]
star_df = star_df.rename(columns={'s_latitude' : 'latitude', 's_longitude': 'longitude' })
apt_df = result[['아파트명', 'latitude', 'longitude']]

# %%
apt_df.to_c
# Out:
#                     아파트명   latitude   longitude
# 0              성안마을청구아파트  37.531677  127.124699
# 1               삼성광나루아파트  37.554106  127.127160
# 2             포남동주공1차아파트  37.775578  128.911832
# 3           금강펜테리움2단지아파트  37.418310  127.274827
# 4          e편한세상태재1단지아파트  37.358219  127.149894
# ..                   ...        ...         ...
# 244  김포풍무꿈에그린유로메트로1단지아파트  37.605378  126.722912
# 245         미사강변센트럴자이아파트  37.557440  127.185921
# 246             해운대엘시티더샵  35.159921  129.169756
# 247          목동세종그랑시아아파트  37.538333  126.864076
# 248      다람마을월드메르디앙2차아파트  37.213851  127.035242
#
# [249 rows x 3 columns]

# %%
star_df
# Out:
#                 지점명   latitude   longitude
# 0      스타벅스 강동구청DT점  37.476169  126.965005
# 1      스타벅스 강동암사DT점  37.643938  126.787386
# 2      스타벅스 강릉송정DT점  35.204197  128.580572
# 3    스타벅스 경기광주송정DT점  29.298528   42.550960
# 4    스타벅스 경기광주신현DT점  37.189891  127.059202
# ..              ...        ...         ...
# 244     스타벅스 풍무역DT점  36.334968  127.396729
# 245    스타벅스 하남미사DT점  36.351462  127.339981
# 246  스타벅스 해운대달맞이DT점  35.242151  129.220117
# 247      스타벅스 화곡DT점  36.638517  127.459838
# 248    스타벅스 화성병점DT점  35.814602  127.123425
#
# [249 rows x 3 columns]

# %%
result = x.copy()

# %%
result[result['longitude'].isnull()]
# Out:
# Empty DataFrame
# Columns: [지점명, 아파트명, 주소, 준공년월, 세대, latitude, longitude, 아파트유무, s_latitude, s_longitude]
# Index: []

# %%
for i in [9, 10, 15]:
    result.loc[i, 'latitude'] = 0
    result.loc[i, 'longitude'] = 0

# %%
merged_df
# Out:
#                   지점명             아파트명                   주소     준공년월      세대  \
# 0     스타벅스 국립대구박물관DT점  황금동캐슬골드파크1단지아파트       대구 수성구 청수로 213  2006.07  1059.0
# 1     스타벅스 대구영대병원역DT점     봉덕동우인그레이스아파트       대구 남구 중앙대로 114  2016.01    16.0
# 2       스타벅스 경주터미널DT점          동부이끌림6차   경북 경주시 금성로247번길 15  2014.06    50.0
# 3     스타벅스 대구수성네거리DT점           롬바드아파트       대구 수성구 들안로 325  2011.07   108.0
# 4        스타벅스 광주매곡DT점          용봉주공아파트         광주 북구 매곡로 20      NaN     NaN
# ..                ...              ...                  ...      ...     ...
# 244   스타벅스 울산중리사거리DT점        평창현대3차아파트   울산 남구 삼산중로128번길 21  1995.10   782.0
# 245  스타벅스 리버사이드팔당DTR점          한강우성아파트  경기 남양주시 와부읍 덕소로 270  1998.07  1488.0
# 246     스타벅스 경주보문로DT점              NaN                  NaN      NaN     NaN
# 247     스타벅스 공주동학사DT점              NaN                  NaN      NaN     NaN
# 248    스타벅스 경주보문호수DT점              NaN                  NaN      NaN     NaN
#
# ...

# %%
merged_df.loc[0, 'latitude_y'] = 36.496008
merged_df.loc[0, 'longitude_y'] =  127.254332
merged_df.loc[0, 'latitude_x'] = 36.48685140000001
merged_df.loc[0, 'longitude_x'] = 127.2526621

# %%
def get_distance(row):
    try:
        return geopy.distance.vincenty((row.latitude_x,row.longitude_x), (row.latitude_y,row.longitude_y)).km
    except:
        return 9999
merged_df['distance'] = merged_df.apply(lambda row:get_distance(row), axis=1)
merged_df
# Out:
# <ipython-input-290-75b7c884eeb7>:3: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   return geopy.distance.vincenty((row.latitude_x,row.longitude_x), (row.latitude_y,row.longitude_y)).km
#                 지점명          아파트명                              주소     준공년월  \
# 0      스타벅스 광주신안DT점   용봉신안고운하이플러스                광주 북구 서암대로 95-29      NaN
# 1      스타벅스 안양호계DT점        내안애팰리스          경기 안양시 동안구 흥안대로94번길 68  2009.12
# 2      스타벅스 김해진영DT점         대한아파트        경남 김해시 진영읍 여래로20번길 64-63  1995.06
# 3     스타벅스 광주신세계DT점  화정동삼익맨션1차아파트                   광주 서구 죽봉대로 31  1979.07
# 4      스타벅스 수원권선DT점  오목천서희스타힐스아파트  경기 수원시 권선구 온정로9번길 36 서희스타힐스아파트  2016.12
# ..              ...           ...                             ...      ...
# 244    스타벅스 전남광양DT점    광양e편한세상아파트                   전남 광양시 시청로 62  2016.06
# ...

# %%
merged_df = merged_df.sort_values('distance').reset_index(drop=True)
merged_df
# Out:
#                 지점명          아파트명                        주소     준공년월     세대  \
# 0      스타벅스 대구중동DT점   수성효성해링턴플레이스          대구 수성구 희망로24길 24  2020.02  745.0
# 1      스타벅스 광주신안DT점   용봉신안고운하이플러스          광주 북구 서암대로 95-29      NaN    NaN
# 2      스타벅스 안양호계DT점        내안애팰리스    경기 안양시 동안구 흥안대로94번길 68  2009.12  100.0
# 3      스타벅스 김해진영DT점         대한아파트  경남 김해시 진영읍 여래로20번길 64-63  1995.06  100.0
# 4     스타벅스 광주신세계DT점  화정동삼익맨션1차아파트             광주 서구 죽봉대로 31  1979.07  276.0
# ..              ...           ...                       ...      ...    ...
# 244  스타벅스 남양산IC DT점    양우내안애6차에코뷰        경남 양산시 동면 금오15길 29  2017.05  581.0
# 245    스타벅스 광주선운DT점  선운이지더원2단지아파트           광주 광산구 선운중앙로 43  2014.07  378.0
# 246   스타벅스 경주보문로DT점           NaN                       NaN      NaN    NaN
# 247   스타벅스 공주동학사DT점           NaN                       NaN      NaN    NaN
# 248  스타벅스 경주보문호수DT점           NaN                       NaN      NaN    NaN
#
# ...

# %%
merged_df.sort_values('distance')[-20:]
# Out:
#                 지점명                 아파트명                       주소     준공년월  \
# 229    스타벅스 충남보령DT점         금성백조예미지2차아파트         충남 보령시 명천동 산38-9  2019.11
# 230    스타벅스 김해대로DT점         김해부원역푸르지오아파트         경남 김해시 김해대로 2326  2014.08
# 231    스타벅스 제주용담DT점                가나아파트          제주 제주시 성화로1길 33  1992.12
# 232     스타벅스 창원역DT점       창원중동유니시티1단지아파트        경남 창원시 의창구 중동로 34  2019.06
# 233    스타벅스 서산예천DT점         e편한세상서산예천아파트          충남 서산시 동서1로 230  2017.02
# 234    스타벅스 광주용두DT점  광주첨단2지구제일풍경채리버파크아파트          광주 북구 첨단연신로 216  2014.05
# 235    스타벅스 인천송도DT점         송도웰카운티4단지아파트        인천 연수구 해송로30번길 20  2010.02
# 236    스타벅스 김해외동DT점             e편한세상봉황역  경남 김해시 김해대로2324번길 54-27  2017.06
# 237    스타벅스 광주주월DT점           힐스테이트백운아파트        광주 남구 회재로1293번길 7  2016.09
# 238     스타벅스 평촌역DT점          인덕원푸르지오엘센트로         경기 의왕시 안양판교로 100  2019.11
# 239    스타벅스 포항장성DT점      포항장성두산위브더제니스아파트     경북 포항시 북구 새천년대로 1235  2010.12
# ...

# %%
merged_df.loc[237, 'address'] = '대구 수성구 희망로24길 24'
merged_df.loc[237, 'latitude_y'] = 35.846206
merged_df.loc[237, 'longitude_y'] = 128.611414

merged_df.loc[238, 'address'] = '인천광역시 남구 학익1동 매소홀로 368'
merged_df.loc[238, 'latitude_y'] = 37.440475
merged_df.loc[238, 'longitude_y'] = 126.662757

merged_df.loc[239, 'address'] = '경기도 여주군 여주읍 점봉리 429-12'
merged_df.loc[239, 'latitude_y'] = 37.266224
merged_df.loc[239, 'longitude_y'] = 127.638154

merged_df.loc[240, 'address'] = '전라남도 목포시 상동 131-10'
merged_df.loc[240, 'latitude_y'] = 34.810210
merged_df.loc[240, 'longitude_y'] = 126.417107

merged_df.loc[241, 'address'] = '광주광역시 광산구 수완동 699-27'
merged_df.loc[241, 'latitude_y'] = 35.203230
merged_df.loc[241, 'longitude_y'] = 126.818724

merged_df.loc[242, 'address'] = '경상북도 포항시 남구 상대동 601-2'
merged_df.loc[242, 'latitude_y'] = 36.015594
merged_df.loc[242, 'longitude_y'] = 129.353048

merged_df.loc[243, 'address'] = '울산광역시 북구 농소2동 546-2'
merged_df.loc[243, 'latitude_y'] = 35.637989
merged_df.loc[243, 'longitude_y'] = 129.345312

merged_df.loc[244, 'address'] = '전라남도 광양시 중동 1321-5'
merged_df.loc[244, 'latitude_y'] = 34.943108
merged_df.loc[244, 'longitude_y'] = 127.697944

merged_df.loc[245, 'address'] = '부산광역시 해운대구 중동 달맞이길 57'
merged_df.loc[245, 'latitude_y'] = 35.161563
merged_df.loc[245, 'longitude_y'] = 129.171237

# %%
merged_df.to_csv('final_starbucks_apt_distance_information.csv', sep='\t')

# %%
def set_coordinates(df, idx, coords):
    df.loc[idx, 's_latitude'] = coords[0]
    df.loc[idx, 's_longitude'] = coords[1]
    print(df.loc[idx, 's_latitude'], df.loc[idx, 's_longitude'])

# %%
set_coordinates(result, 195, (37.4403818, 126.6627574))
set_coordinates(result, 16, (37.4391914, 126.9937285))
set_coordinates(result, 213, (37.1436702, 128.2132028))
set_coordinates(result, 100, (37.520177, 129.114759))
set_coordinates(result, 215, (35.1748448, 128.0929016))
set_coordinates(result, 3, (37.409785, 127.260213))
set_coordinates(result, 93, (37.888925, 127.0570663))
set_coordinates(result, 168, (35.5310243, 129.3301122))
result.loc[120, 'latitude'] = 36.48685140000001
result.loc[120, 'longitude'] = 127.2526621
# Out:
# 37.4403818 126.6627574
# 37.4391914 126.9937285
# 37.1436702 128.2132028
# 37.520177 129.114759
# 35.1748448 128.0929016
# 37.409785 127.260213
# 37.888925 127.0570663
# 35.5310243 129.3301122

# %%
result.to_csv('starbucks_apt_info_20200703.csv', sep='\t')

# %% [raw]
# result.loc[195, 's_latitude'], result.loc[195, 's_longiutde'] = 37.4403818, 126.6627574
# result.loc[16, 's_latitude'], result.loc[16, 's_longiutde'] = 37.4391914, 126.9937285
# result.loc[213, 's_latitude'], result.loc[213, 's_longiutde'] = 37.1436702, 128.2132028
# result.loc[100, 's_latitude'], result.loc[100, 's_longiutde'] = 37.520177, 129.114759
# result.loc[215, 's_latitude'], result.loc[215, 's_longiutde'] = 35.1748448, 128.0929016
# result.loc[3, 's_latitude'], result.loc[3, 's_longiutde'] = 37.409785, 127.260213

# %%
travel_df = x[['loc_name', 'address2', 'num_review']]
travel_df = travel_df.rename(columns={'address2':'address'})
travel_df
# Out:
#        loc_name                       address  num_review
# 0       을왕리해수욕장           인천광역시 중구 을왕로13번길 15      455237
# 1       장경리해수욕장      인천광역시 옹진군 영흥면 영흥로757번길 6       42274
# 2       하나개해수욕장           인천광역시 중구 무의동 산189번지       69251
# 3        왕산해수욕장                  인천광역시 중구 을왕동       92943
# 4          수기해변  인천광역시 옹진군 북도면 시도로86번길 291-48       34234
# ...         ...                           ...         ...
# 9520  강촌 출렁다리공원         강원도 춘천시 남산면 강촌리 671-5         930
# 9521    강촌 번지점프           강원도 춘천시 남산면 강촌로 256         522
# 9522  천등산전통발효식품         충청북도 충주시 산척면 세고개로 277         671
# 9523       살둔계곡              강원도 홍천군 내면 살둔길 3        1393
# 9524        소금산               강원도 원주시 지정면 간현리        1374
#
# [9525 rows x 3 columns]

# %%
travel_df.to_csv('/Users/dhkim/PycharmProjects/kakomap_crwal/data/2020-07-02_18_46_travel_crawl.csv', sep='\t')

# %%
travel_df = travel_df.drop_duplicates('loc_name')

# %%
travel_df = travel_df.drop_duplicates('address').reset_index(drop=True)

# %%
travel_df.to_csv('/Users/dhkim/PycharmProjects/kakomap_crwal/data/2020-07-02_18_46_travel_crawl.csv', sep='\t')

# %%
start_bucks_dt = pd.read_csv('/Users/dhkim/PycharmProjects/kakomap_crwal/data/mac/ST_MAC2_DT.csv', sep='\t')
start_bucks_dt = start_bucks_dt.drop('Unnamed: 0', axis=1)
start_bucks_dt
# Out:
#           mac_name   latitude   longitude  SORT
# 0       맥도날드 양평SK점  37.530980  126.893343  맥도날드
# 1     맥도날드 양천구청DT점  37.515464  126.862954  맥도날드
# 2        맥도날드 고척DT  37.497228  126.863535  맥도날드
# 3       맥도날드 염창DT점  37.552891  126.870164  맥도날드
# 4       맥도날드 서초GS점  37.486421  127.009869  맥도날드
# ..             ...        ...         ...   ...
# 465   스타벅스 목포터미널DT  34.810016  126.417053  스타벅스
# 466    스타벅스 마산회원DT  35.220657  128.574434  스타벅스
# 467     스타벅스 평촌역DT  37.396431  126.969419  스타벅스
# 468    스타벅스 시흥대야DT  37.443912  126.790755  스타벅스
# 469  스타벅스 수원경수인계DT  37.267928  127.027944  스타벅스
#
# [470 rows x 4 columns]

# %%
start_bucks_dt = start_bucks_dt[start_bucks_dt.SORT=='스타벅스'].reset_index(drop=True)

# %%
start_bucks_dt = start_bucks_dt.rename(columns={'mac_name':'star_name'})
start_bucks_dt
# Out:
#          star_name   latitude   longitude  SORT
# 0      스타벅스 울산신정DT  35.544170  129.324735  스타벅스
# 1     스타벅스 경주보문로DT  35.853218  129.268695  스타벅스
# 2       스타벅스 동수원DT  37.278015  127.033828  스타벅스
# 3       스타벅스 서귀포DT  33.249525  126.506710  스타벅스
# 4     스타벅스 구미금오산DT  36.122231  128.323599  스타벅스
# ..             ...        ...         ...   ...
# 249   스타벅스 목포터미널DT  34.810016  126.417053  스타벅스
# 250    스타벅스 마산회원DT  35.220657  128.574434  스타벅스
# 251     스타벅스 평촌역DT  37.396431  126.969419  스타벅스
# 252    스타벅스 시흥대야DT  37.443912  126.790755  스타벅스
# 253  스타벅스 수원경수인계DT  37.267928  127.027944  스타벅스
#
# [254 rows x 4 columns]

# %%
start_bucks_dt.to_csv('starbucks_location_info.csv', sep='\t')

# %%
import pandas as pd
import geopy.distance


def get_distances_with_df(df1, df2, df1_basis, df2_basis):
    rows = []
    for j in range(df1.shape[0]):
        loc_name1 = df1.loc[j][df1_basis]
        coord1 = (df1.loc[j].latitude, df1.loc[j].longitude)
        for i in range(df2.shape[0]):
            loc_name2 = df2.loc[i][df2_basis]
            coord2 = (df2.loc[i].latitude, df2.loc[i].longitude)
            distance = geopy.distance.vincenty(coord1, coord2).km
            row = {
                df1_basis : loc_name1,
                df2_basis : loc_name2,
                'distance': distance
            }
            rows.append(row)
    return rows


def find_mindist_starbucks(groupped_df, basis_name='star_name'):
    new_df = {}
#     groupped_df = groupped_df.reset_index(drop=True)
    groupped_df = groupped_df.sort_values(by='distance').reset_index(drop=True)
    new_df['distance'] = groupped_df.loc[:2]['distance']
    new_df[basis_name] = groupped_df.loc[:2][basis_name]

    return pd.Series(new_df, index=[basis_name, 'distance'])



def main():
    loc_info = pd.read_csv('../data/mac/ST_MAC2_DT.csv', sep='\t')
    loc_info_mac = loc_info[loc_info.SORT == '맥도날드']
    loc_info_star = loc_info[loc_info.SORT == '스타벅스']
    loc_info_star = loc_info_star.reset_index().drop('index', axis=1)

    loc_info_mac = loc_info_mac.drop_duplicates().reset_index(drop=True)

    rows = get_distances_with_st(loc_info_mac, loc_info_star)
    mac_star_distance = pd.DataFrame(rows)
    mac_star_distance2 = mac_star_distance.groupby(['mac_name']).apply(find_mindist_starbucks)
    mac_star_distance3 = mac_star_distance2.reset_index()
    mac_star_distance3.to_csv('data/mac_star_distance2.csv', sep='\t')

# if __name__ == '__main__':;;
#     main()

# %%
rows = get_distances_with_df(start_bucks_dt, travel_df, 'star_name', '')

# %%
import urllib
import json
from pprint import pprint


url = "http://apis.data.go.kr/1160100/service/GetCorpBasicInfoService/getCorpOutline"

ServiceKey = "2cJ3wHYxZ7tLO8fc%2FU6B8jutjQd%2F6FjQBmBZMBljRnfA2uWyeUx1BfUrPL9PLA2oKiAAaUkSOGLiPErkfSXecQ%3D%3D"
company = urllib.parse.quote('디아이동일')
ServiceKey = urllib.parse.unquote(ServiceKey)
query = f"http://apis.data.go.kr/1160100/service/GetCorpBasicInfoService/getCorpOutline?pageNo=1&numOfRows=1&resultType=xml&fnccmpNm={company}&serviceKey={ServiceKey}"
print(query)
request = urllib.request.Request(query)

response = urllib.request.urlopen(request)
rescode = response.getcode()
response_body = ''
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
    dict_ = json.loads(response_body.decode('utf-8'))
    pprint(dict_)
# else:
#     print("Error Code:" + rescode)
# Out:
# http://apis.data.go.kr/1160100/service/GetCorpBasicInfoService/getCorpOutline?pageNo=1&numOfRows=1&resultType=xml&fnccmpNm=%EB%94%94%EC%95%84%EC%9D%B4%EB%8F%99%EC%9D%BC&serviceKey=2cJ3wHYxZ7tLO8fc/U6B8jutjQd/6FjQBmBZMBljRnfA2uWyeUx1BfUrPL9PLA2oKiAAaUkSOGLiPErkfSXecQ==
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL SERVICE.</resultMsg>
#     </header>
#     <body>
#         <numOfRows>1</numOfRows>
#         <pageNo>1</pageNo>
#         <totalCount>1221990</totalCount>
#         <items>
#             <item>
#                 <actnAudpnNm></actnAudpnNm>
#                 <audtRptOpnnCtt></audtRptOpnnCtt>
#                 <basDt>20200627</basDt>
#                 <bzno></bzno>
#                 <corpDcd></corpDcd>
#                 <corpDcdNm></corpDcdNm>
#                 <corpEnsnNm></corpEnsnNm>
#                 <corpNm>(유)서해푸드</corpNm>
# ...
