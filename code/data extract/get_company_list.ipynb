# %%
import pandas as pd
# Out:
# /Users/dhkim/PycharmProjects/untitled/venv/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
company_list = pd.read_excel('/Users/dhkim/Downloads/코스피_800.xls', sep=',')
company_names = company_list['기업명'].values

# %%
company_list
# Out:
#       번호    종목코드      기업명    업종코드               업종     상장주식수(주)  \
# 0      1   95570   AJ네트웍스  147603  산업용 기계 및 장비 임대업   46,822,295
# 1      2    6840    AK홀딩스  116409           기타 금융업   13,247,561
# 2      3   27410      BGF  116409           기타 금융업   95,716,791
# 3      4  282330   BGF리테일   74701           종합 소매업   17,283,906
# 4      5  138930  BNK금융지주  116409           기타 금융업  325,935,246
# ..   ...     ...      ...     ...              ...          ...
# 795  796   79980      휴비스   32005         화학섬유 제조업   34,500,000
# 796  797    5010      휴스틸   32401        1차 철강 제조업    7,621,668
# 797  798   69260      휴켐스   32004      기타 화학제품 제조업   40,878,588
# 798  799     540     흥국화재  116501              보험업   64,242,645
# 799  800    3280     흥아해운   85001           해상 운송업  112,112,392
#
#                 자본금(원) 액면가(원)    통화구분
# 0       46,822,295,000  1,000  원(KRW)
# 1       66,237,805,000  5,000  원(KRW)
# 2       95,716,791,000  1,000     NaN
# 3       17,283,906,000  1,000  원(KRW)
# ...

# %%
company_names
# Out:
# array(['AJ네트웍스', 'AK홀딩스', 'BGF', 'BGF리테일', 'BNK금융지주', 'BYC', 'CJ',
#        'CJ CGV', 'CJ대한통운', 'CJ씨푸드', 'CJ제일제당', 'CS홀딩스', 'DB', 'DB금융투자',
#        'DB손해보험', 'DB하이텍', 'DGB금융지주', 'DRB동일', 'DSR', 'DSR제강', 'E1', 'F&F',
#        'GKL', 'GS', 'GS건설', 'GS글로벌', 'GS리테일', 'HDC', 'HDC아이콘트롤스',
#        'HDC현대EP', 'HDC현대산업개발', 'HSD엔진', 'JB금융지주', 'JW생명과학', 'JW중외제약',
#        'JW홀딩스', 'KB금융', 'KC그린홀딩스', 'KC코트렐', 'KEC', 'KG케미칼', 'KISCO홀딩스',
#        'KPX케미칼', 'KPX홀딩스', 'KR모터스', 'KSS해운', 'KTB투자증권', 'KTcs', 'KTis',
#        'LF', 'LG', 'LG디스플레이', 'LG상사', 'LG생활건강', 'LG유플러스', 'LG이노텍', 'LG전자',
#        'LG하우시스', 'LG헬로비전', 'LG화학', 'LIG넥스원', 'LS', 'LS네트웍스', 'LS산전',
#        'LS전선아시아', 'MH에탄올', 'NAVER', 'NH투자증권', 'NH프라임리츠', 'NICE', 'NI스틸',
#        'OCI', 'S&TC', 'S&T모티브', 'S&T중공업', 'S&T홀딩스', 'S-Oil', 'SBS',
#        'SBS미디어홀딩스', 'SG세계물산', 'SG충방', 'SH에너지화학', 'SIMPAC', 'SK', 'SKC',
#        'SK가스', 'SK네트웍스', 'SK디스커버리', 'SK디앤디', 'SK렌터카', 'SK이노베이션', 'SK증권',
# ...

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import json
from pprint import pprint

# %%
url = 'http://apis.data.go.kr/1160100/service/GetCorpBasicInfoService/getCorpOutline'
decode_key = unquote('2cJ3wHYxZ7tLO8fc%2FU6B8jutjQd%2F6FjQBmBZMBljRnfA2uWyeUx1BfUrPL9PLA2oKiAAaUkSOGLiPErkfSXecQ%3D%3D')
# decode_key = '2cJ3wHYxZ7tLO8fc%2FU6B8jutjQd%2F6FjQBmBZMBljRnfA2uWyeUx1BfUrPL9PLA2oKiAAaUkSOGLiPErkfSXecQ%3D%3D'
queryParams = '?' + urlencode({
    quote_plus('pageNo') : '1',
    quote_plus('numOfRows') : '10',
    quote_plus('resultType') : 'json',
    quote_plus('ServiceKey') : decode_key})
print(url + queryParams)
request = Request(url + queryParams)
request.get_method = lambda: 'GET'
response = urlopen(request)
rescode = response.getcode()
response_body = response.read()
dict_ = json.loads(response_body.decode('utf-8'))
dict_
# Out:
# http://apis.data.go.kr/1160100/service/GetCorpBasicInfoService/getCorpOutline?pageNo=1&numOfRows=10&resultType=json&ServiceKey=2cJ3wHYxZ7tLO8fc%2FU6B8jutjQd%2F6FjQBmBZMBljRnfA2uWyeUx1BfUrPL9PLA2oKiAAaUkSOGLiPErkfSXecQ%3D%3D
# {'response': {'body': {'items': {'item': [{'basDt': '20200627',
#       'crno': '2148140009471',
#       'corpNm': '(유)서해푸드',
#       'corpEnsnNm': '',
#       'enpPbanCmpyNm': '',
#       'enpRprFnm': '',
#       'corpRegMrktDcd': '',
#       'corpRegMrktDcdNm': '',
#       'corpDcd': '',
#       'corpDcdNm': '',
#       'bzno': '',
#       'enpOzpno': '',
#       'enpBsadr': '전라북도 김제시',
#       'enpDtadr': '순동2길 201 (순동)',
#       'enpHmpgUrl': '',
#       'enpTlno': '01086737717',
#       'enpFxno': '',
#       'sicNm': '',
#       'enpEstbDt': '',
#       'enpStacMm': '',
#       'enpXchgLstgDt': '',
#       'enpXchgLstgAbolDt': '',
#       'enpKosdaqLstgDt': '',
#       'enpKosdaqLstgAbolDt': '',
#       'enpKrxLstgDt': '',
#       'enpKrxLstgAbolDt': '',
# ...

# %%
def get_company_info(company_name):
    url = 'http://apis.data.go.kr/1160100/service/GetCorpBasicInfoService/getCorpOutline'
    decode_key = unquote('2cJ3wHYxZ7tLO8fc%2FU6B8jutjQd%2F6FjQBmBZMBljRnfA2uWyeUx1BfUrPL9PLA2oKiAAaUkSOGLiPErkfSXecQ%3D%3D')
    # decode_key = '2cJ3wHYxZ7tLO8fc%2FU6B8jutjQd%2F6FjQBmBZMBljRnfA2uWyeUx1BfUrPL9PLA2oKiAAaUkSOGLiPErkfSXecQ%3D%3D'
    queryParams = '?' + urlencode({
        quote_plus('pageNo') : '1',
        quote_plus('numOfRows') : '10',
        quote_plus('resultType') : 'json',
        quote_plus('corpNm') : company_name,
        quote_plus('ServiceKey') : decode_key})
    request = Request(url + queryParams)
    request.get_method = lambda: 'GET'
    response = urlopen(request)
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        dict_ = json.loads(response_body.decode('utf-8'))
        print(f'{company_name} complete...')
#         pprint(dict_)
    else:
        print("Error Code:" + rescode)
    result = {}
    result['company_name'] = company_name
    result['address1'] = list(set([x['enpBsadr'] for x in dict_['response']['body']['items']['item']]))
    result['address2'] = list(set([x['enpDtadr'] for x in dict_['response']['body']['items']['item']]))
    result['종업원수'] = list(set([x['enpEmpeCnt'] for x in dict_['response']['body']['items']['item']]))
    result['중소기업유무'] = list(set([x['smenpYn'] for x in dict_['response']['body']['items']['item']]))
    print(result)
    return result

# %%
results = []
for name in company_names:
    result = get_company_info(name+'(주)')
    if len(result['address1']) == 0:  
        result = get_company_info(name)
    if len(result['address1']) == 0:  
        result = get_company_info('(주)'+name)
    results.append(result)
results
# Out:
# AJ네트웍스(주) complete...
# {'company_name': 'AJ네트웍스(주)', 'address1': [], 'address2': [], '종업원수': [], '중소기업유무': []}
# AJ네트웍스 complete...
# {'company_name': 'AJ네트웍스', 'address1': ['서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)'], 'address2': ['서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)'], '종업원수': ['531'], '중소기업유무': ['']}
# AK홀딩스(주) complete...
# {'company_name': 'AK홀딩스(주)', 'address1': ['서울특별시 마포구 양화로 188 -', '서울 마포구 양화로 188'], 'address2': ['서울특별시 마포구 양화로 188 -', '(동교동)'], '종업원수': ['20', '0'], '중소기업유무': ['']}
# BGF(주) complete...
# {'company_name': 'BGF(주)', 'address1': [], 'address2': [], '종업원수': [], '중소기업유무': []}
# BGF complete...
# {'company_name': 'BGF', 'address1': [], 'address2': [], '종업원수': [], '중소기업유무': []}
# (주)BGF complete...
# {'company_name': '(주)BGF', 'address1': [], 'address2': [], '종업원수': [], '중소기업유무': []}
# BGF리테일(주) complete...
# {'company_name': 'BGF리테일(주)', 'address1': [], 'address2': [], '종업원수': [], '중소기업유무': []}
# BGF리테일 complete...
# ...

# %%
temp = pd.DataFrame(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b2f958a547c8> in <module>
# ----> 1 temp = pd.DataFrame(results)
#
# NameError: name 'results' is not defined

# %%
temp = temp.rename({'company_name' : '기업명'}, axis=1)

# %%
temp = temp.reset_index()

# %%
temp
# Out:
#      index        기업명                                           address1  \
# 0        0     AJ네트웍스                     [서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)]
# 1        1   AK홀딩스(주)              [서울특별시 마포구 양화로 188 -, 서울 마포구 양화로 188]
# 2        2     (주)BGF                                                 []
# 3        3  (주)BGF리테일                                                 []
# 4        4    BNK금융지주                           [부산광역시 남구 문현금융로 30(문현동)]
# ..     ...        ...                                                ...
# 795    795     휴비스(주)  [경기도 성남시 분당구 돌마로 172 (정자동, 분당서울대학교병원헬스케어혁신파크)4...
# 796    796        휴스틸  [서울특별시 강남구  테헤란로 512 (대치동, 신안빌딩 14층), 서울 강남구 테...
# 797    797     휴켐스(주)  [서울특별시 중구  퇴계로 173 19층, 서울 중구 퇴계로 173, 서울 중구 충...
# 798    798       흥국화재                                [서울특별시 종로구 새문안로 68]
# 799    799    흥아해운(주)  [서울특별시 중구 남대문로9길 39 서울시 중구 남대문로9길 39(을지로1가, 부림...
#
#                                               address2      종업원수 중소기업유무
# ...

# %%
company_list = company_list.reset_index()

# %%
company_list
# Out:
#      index   번호    종목코드      기업명    업종코드               업종     상장주식수(주)  \
# 0        0    1   95570   AJ네트웍스  147603  산업용 기계 및 장비 임대업   46,822,295
# 1        1    2    6840    AK홀딩스  116409           기타 금융업   13,247,561
# 2        2    3   27410      BGF  116409           기타 금융업   95,716,791
# 3        3    4  282330   BGF리테일   74701           종합 소매업   17,283,906
# 4        4    5  138930  BNK금융지주  116409           기타 금융업  325,935,246
# ..     ...  ...     ...      ...     ...              ...          ...
# 795    795  796   79980      휴비스   32005         화학섬유 제조업   34,500,000
# 796    796  797    5010      휴스틸   32401        1차 철강 제조업    7,621,668
# 797    797  798   69260      휴켐스   32004      기타 화학제품 제조업   40,878,588
# 798    798  799     540     흥국화재  116501              보험업   64,242,645
# 799    799  800    3280     흥아해운   85001           해상 운송업  112,112,392
#
#                 자본금(원) 액면가(원)    통화구분
# 0       46,822,295,000  1,000  원(KRW)
# ...

# %%
temp[temp['기업명']=='삼성전자(주)']
# Out:
#          기업명                                           address1  \
# 334  삼성전자(주)  [서울 서초구 서초대로74길 11, 경기 양평군 서종면, 경기도 수원시 영통구  삼...
#
#                                               address2                종업원수  \
# 334  [경기도 수원시 영통구  삼성로 129 (매탄동), 756-1, 37층 (서초동, ...  [0, 98541, 105257]
#
#     중소기업유무
# 334     []

# %%
company_list_new = pd.merge(company_list, temp, on='index')

# %%
company_list_new = company_list_new.drop(['index', '번호'], axis=1)

# %%
company_list_new = company_list_new.rename(columns={'기업명_y' :'기업명'})
company_list_new2 = company_list_new[['기업명','종목코드','업종코드','자본금(원)','address1','address2','종업원수']]
company_list_new2
# Out:
#            기업명    종목코드    업종코드             자본금(원)  \
# 0       AJ네트웍스   95570  147603     46,822,295,000
# 1     AK홀딩스(주)    6840  116409     66,237,805,000
# 2       (주)BGF   27410  116409     95,716,791,000
# 3    (주)BGF리테일  282330   74701     17,283,906,000
# 4      BNK금융지주  138930  116409  1,629,676,230,000
# ..         ...     ...     ...                ...
# 795     휴비스(주)   79980   32005    172,500,000,000
# 796        휴스틸    5010   32401     38,108,340,000
# 797     휴켐스(주)   69260   32004     40,878,588,000
# 798       흥국화재     540  116501    325,821,225,000
# 799    흥아해운(주)    3280   85001     56,056,196,000
#
#                                               address1  \
# 0                       [서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)]
# 1                [서울특별시 마포구 양화로 188 -, 서울 마포구 양화로 188]
# 2                                                   []
# 3                                                   []
# 4                             [부산광역시 남구 문현금융로 30(문현동)]
# ...

# %%
company_list_new3 = company_list_new2[company_list_new2['address1'].map(lambda x:bool(len(x)))].reset_index(drop=True)

# %%
company_list_new3
# Out:
#           기업명    종목코드    업종코드             자본금(원)  \
# 0      AJ네트웍스   95570  147603     46,822,295,000
# 1    AK홀딩스(주)    6840  116409     66,237,805,000
# 2     BNK금융지주  138930  116409  1,629,676,230,000
# 3         BYC    1460   31401      4,200,000,000
# 4       CJ(주)    1040  116409    179,047,370,000
# ..        ...     ...     ...                ...
# 732    휴비스(주)   79980   32005    172,500,000,000
# 733       휴스틸    5010   32401     38,108,340,000
# 734    휴켐스(주)   69260   32004     40,878,588,000
# 735      흥국화재     540  116501    325,821,225,000
# 736   흥아해운(주)    3280   85001     56,056,196,000
#
#                                               address1  \
# 0                       [서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)]
# 1                [서울특별시 마포구 양화로 188 -, 서울 마포구 양화로 188]
# 2                             [부산광역시 남구 문현금융로 30(문현동)]
# 3                               [서울특별시 영등포구 도림천로21길 3]
# 4          [서울특별시 중구 소월로2길 12 (남대문로5가, CJ THE CENTER)]
# ...

# %%
import numpy as np

# %%
company_list_new4 = pd.DataFrame({'기업명':np.repeat(company_list_new3.기업명.values, company_list_new3.address1.str.len()),
                        '주소':np.concatenate(company_list_new3.address1.values)})
company_list_new4
# Out:
#            기업명                                                 주소
# 0       AJ네트웍스                       서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)
# 1     AK홀딩스(주)                                서울특별시 마포구 양화로 188 -
# 2     AK홀딩스(주)                                     서울 마포구 양화로 188
# 3      BNK금융지주                             부산광역시 남구 문현금융로 30(문현동)
# 4          BYC                               서울특별시 영등포구 도림천로21길 3
# ...        ...                                                ...
# 1969    휴켐스(주)                                      서울 중구 퇴계로 173
# 1970    휴켐스(주)                                        서울 중구 충무로3가
# 1971      흥국화재                                  서울특별시 종로구 새문안로 68
# 1972   흥아해운(주)  서울특별시 중구 남대문로9길 39 서울시 중구 남대문로9길 39(을지로1가, 부림빌...
# 1973   흥아해운(주)                                         서울 송파구 문정동
#
# [1974 rows x 2 columns]

# %%
company_list_new5 = pd.concat([company_list_new4, handmade_list])
company_list_new5
# Out:
#          기업명                            주소
# 0     AJ네트웍스  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)
# 1   AK홀딩스(주)           서울특별시 마포구 양화로 188 -
# 2   AK홀딩스(주)                서울 마포구 양화로 188
# 3    BNK금융지주        부산광역시 남구 문현금융로 30(문현동)
# 4        BYC          서울특별시 영등포구 도림천로21길 3
# ..       ...                           ...
# 42  (주)한화/기계             경남 창원시 성산구 성산패총로9
# 43  (주)한화/기계    충청남도 아산시 둔포면 해위안길 62번지길 16
# 44  (주)한화/기계           경기도 성남시 분당구 판교로 305
# 45  (주)한화/기계        충청남도 아산시 둔포면 아산밸리로 312
# 46  SK Hynix         경기도 이천시 부발읍 경충대로 2091
#
# [2020 rows x 2 columns]

# %%
company_list_new5.to_csv('big_company_address_with_factory.csv', sep='\t')

# %%
handmade_list = pd.read_excel('/Users/dhkim/PycharmProjects/company_list/handmade_list.xlsx')
handmade_list = handmade_list.iloc[1:,:].rename(columns={'handmade_list':'기업명', 'Unnamed: 1':'주소'})
handmade_list
# Out:
#          기업명                             주소
# 1       현대제철    서울특별시 서초구 헌릉로 12 현대기아차사옥 서관
# 2       현대제철        충청남도 당진시 송악읍 북부산업로 1480
# 3       현대제철               인천광역시 동구 중봉대로 63
# 4       현대제철          경상북도 포항시 남구 동해안로 6363
# 5       현대제철           전라남도 순천시 해룡면 인덕로 300
# 6       현대제철               울산광역시 북구 염포로 706
# 7       현대제철           충청남도 예산군 삽교읍 효림리 555
# 8       삼성전자       경기도 수원시 영통구 삼성로 129(매탄동)
# 9       삼성전자           경북 구미시 1공단로 244(공단동)
# 10      삼성전자          경북 구미시 3공단3로 302(임수동)
# 11      삼성전자         경기도 용인시 기흥구 삼성로 1(농서동)
# 12      삼성전자           경기도 화성시 삼성전자로 1(반월동)
# 13      삼성전자    광주광역시 광산구 하남산단 6번로 107(오선동)
# 14      삼성전자           광주광역시 북구 앰코로 70(오룡동)
# 15      삼성전자           충청남도 아산시 배방읍 배방로 158
# 16      삼성전자            경기도 평택시 고덕면 삼성로 114
# 17      삼성전자          서울특별시 서초구 성촌길 33(우면동)
# 18   삼성디스플레이              경기도 용인시 기흥구 삼성로 1
# 19   삼성디스플레이           충청남도 아산시 탕정면 삼성로 181
# 20   삼성디스플레이           충청남도 천안시 서북구 번영로 465
# ...

# %%
company_list_new5 = company_list_new5.reset_index(drop=True)

# %%
company_list_new5 = company_list_new5.drop_duplicates('주소').reset_index(drop=True)
company_list_new5.to_csv('big_company_address_with_factory.csv', sep='\t')

# %%
company_list_new5
# Out:
#            기업명                            주소
# 0       AJ네트웍스  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)
# 1     AK홀딩스(주)           서울특별시 마포구 양화로 188 -
# 2     AK홀딩스(주)                서울 마포구 양화로 188
# 3      BNK금융지주        부산광역시 남구 문현금융로 30(문현동)
# 4          BYC          서울특별시 영등포구 도림천로21길 3
# ...        ...                           ...
# 1823  (주)한화/기계             경남 창원시 성산구 성산패총로9
# 1824  (주)한화/기계    충청남도 아산시 둔포면 해위안길 62번지길 16
# 1825  (주)한화/기계           경기도 성남시 분당구 판교로 305
# 1826  (주)한화/기계        충청남도 아산시 둔포면 아산밸리로 312
# 1827  SK Hynix         경기도 이천시 부발읍 경충대로 2091
#
# [1828 rows x 2 columns]

# %%
find_lat_lng('제주 서귀포시 천제연로 95')
# Out:
# (33.2549983, 126.4159059)

# %%
import requests
# from utils.csv_postprocess import postprocess_df
import time


def find_lat_lng(location):
    # 요청 주소(구글맵)

    # Production(실제 서비스) 환경 - https 요청이 필수이고, API Key 발급(사용설정) 및 과금 설정이 반드시 필요합니다.
    URL = 'https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBWgPcQF1nWKXIwGLPJVZA4-QYLw5GdVVM' \
          '&sensor=false&language=ko&address={}'.format(location)
    try:
        # URL로 보낸 Requst의 Response를 response 변수에 할당
        response = requests.get(URL)

        # JSON 파싱
        data = response.json()

        # lat, lon 추출
        lat = data['results'][0]['geometry']['location']['lat']
        lng = data['results'][0]['geometry']['location']['lng']
    except Exception as e:
        print(f'{e} : {location} failed to find coordinates')
        # time.sleep(1)
        # lat, lng = find_lat_lng(location)
        lat, lng = 0, 0
    return lat, lng

def dataframe_loc_convert(df, address_column):
    if isinstance(df, str):
        save_path = df
        import pandas as pd
        df = pd.read_csv(save_path, sep='\t')
    else:
        save_path = 'data/converted_result.csv'

    df['latitude'] = ""
    df['longitude'] = ""

    locs = []
    for i, loc in enumerate(df[address_column]):
        lat, lng = find_lat_lng(loc)
        df['latitude'].iloc[i] = lat
        df['longitude'].iloc[i] = lng
        print(f"{lat}'\t'{lng}")
        locs.append((lat, lng))

    if "Unnamed: 0" in df.columns:
        df = df.drop("Unnamed: 0", axis=1)
    df.to_csv(save_path, sep='\t')
    return save_path

# %%
company_locations = pd.read_csv('/Users/dhkim/PycharmProjects/company_list/new_big_company_address_with_factory.csv', sep='\t')

# %%
company_locations = company_locations.drop(company_locations.columns[0], axis=1)
company_locations
# Out:
#            기업명                            주소   latitude   longitude
# 0       AJ네트웍스  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)  37.485262  127.118094
# 1     AK홀딩스(주)           서울특별시 마포구 양화로 188 -  37.552785  126.918612
# 2     AK홀딩스(주)                서울 마포구 양화로 188  37.552785  126.918612
# 3      BNK금융지주        부산광역시 남구 문현금융로 30(문현동)  35.145384  129.065782
# 4          BYC          서울특별시 영등포구 도림천로21길 3  37.486290  126.901551
# ...        ...                           ...        ...         ...
# 1823  (주)한화/기계             경남 창원시 성산구 성산패총로9  35.198385  128.671024
# 1824  (주)한화/기계    충청남도 아산시 둔포면 해위안길 62번지길 16  36.893872  127.023031
# 1825  (주)한화/기계           경기도 성남시 분당구 판교로 305  37.398551  127.106815
# 1826  (주)한화/기계        충청남도 아산시 둔포면 아산밸리로 312  36.913107  127.062119
# 1827  SK Hynix         경기도 이천시 부발읍 경충대로 2091  37.250125  127.483494
#
# [1828 rows x 4 columns]

# %%
start_bucks_dt = pd.read_csv('./starbucksDT_location_info_20200707.csv', sep=',', index_col=0)
start_bucks_dt
# Out:
#                 지점명   latitude   longitude  \
# 0      스타벅스 강동구청DT점  37.529139  127.123792
# 1      스타벅스 강동암사DT점  37.555040  127.130065
# 2      스타벅스 강릉송정DT점  37.771866  128.922926
# 3    스타벅스 경기광주송정DT점  37.424435  127.262841
# 4    스타벅스 경기광주신현DT점  37.359885  127.153039
# ..              ...        ...         ...
# 247     스타벅스 풍무역DT점  37.610333  126.737431
# 248    스타벅스 하남미사DT점  37.567550  127.189241
# 249  스타벅스 해운대달맞이DT점  35.161563  129.171237
# 250      스타벅스 화곡DT점  37.535035  126.863118
# 251    스타벅스 화성병점DT점  37.212610  127.038229
#
#                                                address
# 0                                              성내동 550
# 1                                           암사동 441-12
# 2    강원도 강릉시 경강로 2402    2020-03-31 18:56:50.526315776
# 3                                        송정동 12-12 1필지
# 4                                            신현리 701-5
# ..                                                 ...
# ...

# %%
import pandas as pd
import geopy.distance


def get_distances_with_st(mac_df, star_df):
    rows = []
    for j in range(mac_df.shape[0]):
        mac_name = mac_df.loc[j].mac_name
        coord1 = (mac_df.loc[j].latitude, mac_df.loc[j].longitude)
        for i in range(star_df.shape[0]):
            star_name = star_df.loc[i].mac_name
            coord2 = (star_df.loc[i].latitude, star_df.loc[i].longitude)
            distance = geopy.distance.vincenty(coord1, coord2).km
            row = {
                'mac_name': mac_name,
                'star_name': star_name,
                'distance': distance
            }
            rows.append(row)
    return rows


def get_distances_with_df(df1, df2, df1_basis, df2_basis):
    rows = []
    for j in range(df1.shape[0]):
        loc_name1 = df1.loc[j][df1_basis]
        coord1 = (df1.loc[j].latitude, df1.loc[j].longitude)
        for i in range(df2.shape[0]):
            loc_name2 = df2.loc[i][df2_basis]
            coord2 = (df2.loc[i].latitude, df2.loc[i].longitude)
            distance = geopy.distance.vincenty(coord1, coord2).km
            row = {
                df1_basis : loc_name1,
                df2_basis : loc_name2,
                'distance': distance
            }
            rows.append(row)
    return rows


def find_mindist_starbucks(each_mac_df, basis_name='star_name'):
    new_df = {}
    each_mac_df = each_mac_df.reset_index(drop=True)
    new_df['distance'] = each_mac_df['distance'].sort_values().reset_index(drop=True)[:]
    new_df[basis_name] = each_mac_df.loc[:2][basis_name]

    return pd.Series(new_df, index=[basis_name, 'distance'])


def main():
    loc_info = pd.read_csv('../data/mac/ST_MAC2_DT.csv', sep='\t')
    loc_info_mac = loc_info[loc_info.SORT == '맥도날드']
    loc_info_star = loc_info[loc_info.SORT == '스타벅스']
    loc_info_star = loc_info_star.reset_index().drop('index', axis=1)

    loc_info_mac = loc_info_mac.drop_duplicates().reset_index(drop=True)

    rows = get_distances_with_st(loc_info_mac, loc_info_star)
    mac_star_distance = pd.DataFrame(rows)
    mac_star_distance2 = mac_star_distance.groupby(['mac_name']).apply(find_mindist_starbucks)
    mac_star_distance3 = mac_star_distance2.reset_index()
    mac_star_distance3.to_csv('data/mac_star_distance2.csv', sep='\t')

# if __name__ == '__main__':;;
#     main()

# %%
rows = get_distances_with_df(df1=start_bucks_dt, df2=company_locations, df1_basis='지점명', df2_basis='기업명' )
# Out:
# <ipython-input-45-60d24b432f9c>:31: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   distance = geopy.distance.vincenty(coord1, coord2).km

# %%
len(rows)
# Out:
# 460656

# %%
star_company_distance = pd.DataFrame(rows)

# %%
star_company_distance = star_company_distance.rename(columns={'loc_name':'지점명', 'loc_name2':'기업명'})
star_company_distance
# Out:
#                  지점명       기업명    distance
# 0       스타벅스 강동구청DT점    AJ네트웍스    4.895769
# 1       스타벅스 강동구청DT점  AK홀딩스(주)   18.322120
# 2       스타벅스 강동구청DT점  AK홀딩스(주)   18.322120
# 3       스타벅스 강동구청DT점   BNK금융지주  316.784718
# 4       스타벅스 강동구청DT점       BYC   20.217024
# ...              ...       ...         ...
# 460651  스타벅스 화성병점DT점  (주)한화/기계  267.410932
# 460652  스타벅스 화성병점DT점  (주)한화/기계   35.398944
# 460653  스타벅스 화성병점DT점  (주)한화/기계   21.513410
# 460654  스타벅스 화성병점DT점  (주)한화/기계   33.306406
# 460655  스타벅스 화성병점DT점  SK Hynix   39.731995
#
# [460656 rows x 3 columns]

# %%
star_company_distance
# Out:
#                  지점명       기업명    distance
# 0       스타벅스 강동구청DT점    AJ네트웍스    4.895769
# 1       스타벅스 강동구청DT점  AK홀딩스(주)   18.322120
# 2       스타벅스 강동구청DT점  AK홀딩스(주)   18.322120
# 3       스타벅스 강동구청DT점   BNK금융지주  316.784718
# 4       스타벅스 강동구청DT점       BYC   20.217024
# ...              ...       ...         ...
# 460651  스타벅스 화성병점DT점  (주)한화/기계  267.410932
# 460652  스타벅스 화성병점DT점  (주)한화/기계   35.398944
# 460653  스타벅스 화성병점DT점  (주)한화/기계   21.513410
# 460654  스타벅스 화성병점DT점  (주)한화/기계   33.306406
# 460655  스타벅스 화성병점DT점  SK Hynix   39.731995
#
# [460656 rows x 3 columns]

# %%
def company_count(groupped_x, distance):
    new_dict = {}
    groupped_x = groupped_x.reset_index()
    cnt = 0
    for idx in range(groupped_x.shape[0]):
        if groupped_x.loc[idx, 'distance'] < distance:
            cnt += 1
    new_dict = {f'{distance}km이내 회사개수':cnt}
    return pd.Series(new_dict)
dict_dist = {}
for dist in [1,2,3,5]:
    dict_dist[dist] = star_company_distance.groupby('지점명').apply(lambda x: company_count(x, dist)).reset_index()

# %%
for dist in [1,2,3,5]:
    dict_dist[dist] = dict_dist[dist].reset_index(drop=True)
    useless_col = ['level_0','index']
    for col in useless_col:
        if col in dict_dist[dist].columns:
            dict_dist[dist] = dict_dist[dist].drop(col, axis=1)

# %%
dict_dist[1].iloc[:,0]
# Out:
# 0        스타벅스 강동구청DT점
# 1        스타벅스 강동암사DT점
# 2        스타벅스 강릉송정DT점
# 3      스타벅스 경기광주송정DT점
# 4      스타벅스 경기광주신현DT점
#             ...
# 247       스타벅스 풍무역DT점
# 248      스타벅스 하남미사DT점
# 249    스타벅스 해운대달맞이DT점
# 250        스타벅스 화곡DT점
# 251      스타벅스 화성병점DT점
# Name: 지점명, Length: 252, dtype: object

# %%
merge_df = pd.DataFrame()
merge_df[dict_dist[1].columns[0]] = dict_dist[1].iloc[:,0]
for dist in [1,2,3,5]:
    dict_dist[dist] = dict_dist[dist].reset_index(drop=True)
    useless_col = ['level_0','index']
    for col in useless_col:
        if col in dict_dist[dist].columns:
            dict_dist[dist] = dict_dist[dist].drop(col, axis=1)
    column_name = dict_dist[dist].columns[-1]
    merge_df[column_name] = dict_dist[dist].iloc[:,-1]
merge_df
# Out:
#                 지점명  1km이내 회사개수  2km이내 회사개수  3km이내 회사개수  5km이내 회사개수
# 0      스타벅스 강동구청DT점           3          13          33          44
# 1      스타벅스 강동암사DT점           0           2          12          29
# 2      스타벅스 강릉송정DT점           0           0           1           2
# 3    스타벅스 경기광주송정DT점           0           1           1           3
# 4    스타벅스 경기광주신현DT점           1           1           3          14
# ..              ...         ...         ...         ...         ...
# 247     스타벅스 풍무역DT점           0           2           3           5
# 248    스타벅스 하남미사DT점           1           2           5           6
# 249  스타벅스 해운대달맞이DT점           0           1           1           2
# 250      스타벅스 화곡DT점           2           7          24          60
# 251    스타벅스 화성병점DT점           3           3           4          13
#
# [252 rows x 5 columns]

# %%
merge_df.to_csv('company_count_with_starbucks_distance.csv', sep='\t')

# %%
star_company_distance['1km이내회사개수'] = dict_dist[1].values

# %%
star_company_distance
# Out:
#                  지점명       기업명    distance  1km이내회사개수
# 0       스타벅스 강동구청DT점    AJ네트웍스    4.895769        NaN
# 1       스타벅스 강동구청DT점  AK홀딩스(주)   18.322120        NaN
# 2       스타벅스 강동구청DT점  AK홀딩스(주)   18.322120        NaN
# 3       스타벅스 강동구청DT점   BNK금융지주  316.784718        NaN
# 4       스타벅스 강동구청DT점       BYC   20.217024        NaN
# ...              ...       ...         ...        ...
# 460651  스타벅스 화성병점DT점  (주)한화/기계  267.410932        NaN
# 460652  스타벅스 화성병점DT점  (주)한화/기계   35.398944        NaN
# 460653  스타벅스 화성병점DT점  (주)한화/기계   21.513410        NaN
# 460654  스타벅스 화성병점DT점  (주)한화/기계   33.306406        NaN
# 460655  스타벅스 화성병점DT점  SK Hynix   39.731995        NaN
#
# [460656 rows x 4 columns]

# %%
star_company_distance.to_csv('starbucks_company_dist_rawdata.csv', sep='\t')

# %%
def find_mindist_starbucks(groupped_df, basis_name='star_name'):
    new_df = {}
#     groupped_df = groupped_df.reset_index(drop=True)
    groupped_df = groupped_df.sort_values(by='distance').reset_index(drop=True)
    new_df['distance'] = groupped_df.loc[:2]['distance']
    new_df[basis_name] = groupped_df.loc[:2][basis_name]

    return pd.Series(new_df, index=[basis_name, 'distance'])

# %%
star_company_distance2 = star_company_distance.groupby(['지점명']).apply(lambda x:find_mindist_starbucks(x,'기업명'))
star_company_distance2 = star_company_distance2.reset_index()
star_company_distance2.to_csv('star_company_distance2.csv', sep='\t')

# %%
star_company_distance2.loc[0]['distance'].values
# star_company_distance2['distance'].values[0]
# Out:
# array([0.13991513, 0.14842249, 0.45781491])

# %%
import numpy as np

# %%
star_company_distance3 = pd.DataFrame({'지점명':np.repeat(star_company_distance2.지점명.values, star_company_distance2.기업명.str.len()),
                        '기업명':np.concatenate(star_company_distance2.기업명.values),'distance:':np.concatenate(star_company_distance2.distance.values)})
star_company_distance3
# Out:
#               지점명         기업명  distance:
# 0    스타벅스 강동구청DT점        일신석재   0.139915
# 1    스타벅스 강동구청DT점        일신석재   0.148422
# 2    스타벅스 강동구청DT점       지코(주)   0.457815
# 3    스타벅스 강동암사DT점       현대홈쇼핑   1.286706
# 4    스타벅스 강동암사DT점       현대홈쇼핑   1.820245
# ..            ...         ...        ...
# 751    스타벅스 화곡DT점          조비   0.971290
# 752    스타벅스 화곡DT점   동양네트웍스(주)   1.047335
# 753  스타벅스 화성병점DT점  우리들휴브레인(주)   0.108317
# 754  스타벅스 화성병점DT점       경동나비엔   0.127057
# 755  스타벅스 화성병점DT점       경동나비엔   0.127057
#
# [756 rows x 3 columns]

# %%
star_company_distance3.to_csv('star_company_distance.csv', sep='\t')

# %%
star_company_distance4 = star_company_distance3.groupby(['지점명','기업명'],as_index=False).min()

# %%
star_company_distance4 = star_company_distance4.rename(columns={'distance:':'distance'})

# %%
star_company_distance4
# Out:
#               지점명         기업명  distance
# 0    스타벅스 강동구청DT점        일신석재  0.139915
# 1    스타벅스 강동구청DT점       지코(주)  0.457815
# 2    스타벅스 강동암사DT점       현대홈쇼핑  1.286706
# 3    스타벅스 강동암사DT점       휠라홀딩스  2.106145
# 4    스타벅스 강릉송정DT점        강원랜드  4.689348
# ..            ...         ...       ...
# 663    스타벅스 화곡DT점   동양네트웍스(주)  1.047335
# 664    스타벅스 화곡DT점        이스타코  0.880115
# 665    스타벅스 화곡DT점          조비  0.971290
# 666  스타벅스 화성병점DT점       경동나비엔  0.127057
# 667  스타벅스 화성병점DT점  우리들휴브레인(주)  0.108317
#
# [668 rows x 3 columns]

# %%
star_company_distance4 = star_company_distance4.sort_values('distance').reset_index(drop=True)
star_company_distance4.to_csv('star_company_distance.csv', sep='\t')

# %%
company_locations
# Out:
#            기업명                            주소   latitude   longitude
# 0       AJ네트웍스  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)  37.485262  127.118094
# 1     AK홀딩스(주)           서울특별시 마포구 양화로 188 -  37.552785  126.918612
# 2     AK홀딩스(주)                서울 마포구 양화로 188  37.552785  126.918612
# 3      BNK금융지주        부산광역시 남구 문현금융로 30(문현동)  35.145384  129.065782
# 4          BYC          서울특별시 영등포구 도림천로21길 3  37.486290  126.901551
# ...        ...                           ...        ...         ...
# 1823  (주)한화/기계             경남 창원시 성산구 성산패총로9  35.198385  128.671024
# 1824  (주)한화/기계    충청남도 아산시 둔포면 해위안길 62번지길 16  36.893872  127.023031
# 1825  (주)한화/기계           경기도 성남시 분당구 판교로 305  37.398551  127.106815
# 1826  (주)한화/기계        충청남도 아산시 둔포면 아산밸리로 312  36.913107  127.062119
# 1827  SK Hynix         경기도 이천시 부발읍 경충대로 2091  37.250125  127.483494
#
# [1828 rows x 4 columns]

# %%
def get_company_info(x):
    condition = (company_list['기업명']==x)
    result = company_list.loc[condition,'자본금(원)']
    if len(result) == 0:
        condition = (company_list['기업명'] + '(주)'==x)
        result = company_list.loc[condition,'자본금(원)']
    if len(result) == 0:
        condition = ('(주)'+company_list['기업명']==x)
        result = company_list.loc[condition,'자본금(원)']
    try:
        return result.values[0]
    except:
        return np.nan
star_company_distance4['자본금'] = star_company_distance4['기업명'].map(lambda x:get_company_info(x))

# %%
company_list.loc[company_list['기업명']=='x','자본금(원)']
# Out:
# 334    897,513,820,000
# Name: 자본금(원), dtype: object

# %%
star_company_distance4.loc[star_company_distance4['자본금'].isnull(),'자본금'] = '1,309,100,000,000'

# %%
star_company_distance4.to_csv('star_company_distance.csv', sep='\t')

# %%
star_company_distance4
# Out:
#                지점명      기업명      distance              자본금
# 0     스타벅스 인천송도DT점       한섬  0.000000e+00   12,315,000,000
# 1     스타벅스 하남미사DT점  이화산업(주)  7.066210e-13   14,000,000,000
# 2       스타벅스 연희DT점  대림통상(주)  3.792249e-02   16,425,000,000
# 3      스타벅스 창원역DT점     주연테크  5.172879e-02   10,675,199,200
# 4    스타벅스 천안IC DT점      윌비스  1.066963e-01   68,786,482,000
# ..             ...      ...           ...              ...
# 663   스타벅스 제주성산DT점  태영건설(주)  3.488613e+01   39,478,740,000
# 664   스타벅스 전북정읍DT점       한창  3.635265e+01   17,395,134,500
# 665   스타벅스 충남보령DT점     현대제철  4.034775e+01  667,228,925,000
# 666     스타벅스 속초DT점     강원랜드  5.495829e+01  106,970,250,000
# 667     스타벅스 속초DT점       대창  5.543060e+01   45,570,249,500
#
# [668 rows x 4 columns]

# %%
star_company_distance4[star_company_distance4['기업명'].map(lambda x:'삼성' in x)]
# Out:
#                   지점명         기업명  distance                자본금
# 56      스타벅스 수원IC DT점     삼성디스플레이  0.681024  1,309,100,000,000
# 60       스타벅스 동탄능동DT점        삼성전자  0.746183    897,513,820,000
# 63       스타벅스 안양비산DT점     삼성공조(주)  0.760896      4,063,157,000
# 95   스타벅스 안양운동장사거리DT점     삼성공조(주)  0.966867      4,063,157,000
# 102      스타벅스 광주선운DT점        삼성전자  1.006450    897,513,820,000
# 106      스타벅스 광주수완DT점        삼성전자  1.038025    897,513,820,000
# 130        스타벅스 제천DT점  삼성엔지니어링(주)  1.189667    980,000,000,000
# 146      스타벅스 수원망포DT점     삼성전자(주)  1.251049    897,513,820,000
# 215       스타벅스 신영통DT점        삼성전자  1.678785    897,513,820,000
# 258    스타벅스 수원KBS DT점     삼성전기(주)  1.910795    388,003,400,000
# 285      스타벅스 광주용두DT점        삼성전자  1.984199    897,513,820,000
# 308      스타벅스 인천동춘DT점  삼성엔지니어링(주)  2.127190    980,000,000,000
# 319      스타벅스 용인보라DT점    삼성SDI(주)  2.173309    356,712,130,000
# 345      스타벅스 하남미사DT점  삼성엔지니어링(주)  2.354995    980,000,000,000
# ...

# %%
start_bucks_dt = start_bucks_dt[start_bucks_dt['SORT'] == '스타벅스'].reset_index(dr)

# %%
start_bucks_dt = start_bucks_dt.rename(columns={'mac_name':'지점명'})

# %%
start_bucks_dt
# Out:
#                지점명   latitude   longitude  SORT
# 0      스타벅스 울산신정DT  35.544170  129.324735  스타벅스
# 1     스타벅스 경주보문로DT  35.853218  129.268695  스타벅스
# 2       스타벅스 동수원DT  37.278015  127.033828  스타벅스
# 3       스타벅스 서귀포DT  33.249525  126.506710  스타벅스
# 4     스타벅스 구미금오산DT  36.122231  128.323599  스타벅스
# ..             ...        ...         ...   ...
# 249   스타벅스 목포터미널DT  34.810016  126.417053  스타벅스
# 250    스타벅스 마산회원DT  35.220657  128.574434  스타벅스
# 251     스타벅스 평촌역DT  37.396431  126.969419  스타벅스
# 252    스타벅스 시흥대야DT  37.443912  126.790755  스타벅스
# 253  스타벅스 수원경수인계DT  37.267928  127.027944  스타벅스
#
# [254 rows x 4 columns]

# %%
start_bucks_loc = pd.read_csv('../starbucksDT/starbucksDT_location_info_20200707.csv', sep='\t', index_col=0)

# %%
start_bucks_loc_select = start_bucks_loc[start_bucks_loc['지점명']=='스타벅스 리버사이드팔당DTR점'].reset_index(drop=True)

# %%
start_bucks_loc_select
# Out:
#                 지점명   latitude   longitude     address
# 0  스타벅스 리버사이드팔당DTR점  37.567097  127.228378  도곡리 504-15

# %%
company_locations
# Out:
#            기업명                            주소   latitude   longitude
# 0       AJ네트웍스  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)  37.485262  127.118094
# 1     AK홀딩스(주)           서울특별시 마포구 양화로 188 -  37.552785  126.918612
# 2     AK홀딩스(주)                서울 마포구 양화로 188  37.552785  126.918612
# 3      BNK금융지주        부산광역시 남구 문현금융로 30(문현동)  35.145384  129.065782
# 4          BYC          서울특별시 영등포구 도림천로21길 3  37.486290  126.901551
# ...        ...                           ...        ...         ...
# 1823  (주)한화/기계             경남 창원시 성산구 성산패총로9  35.198385  128.671024
# 1824  (주)한화/기계    충청남도 아산시 둔포면 해위안길 62번지길 16  36.893872  127.023031
# 1825  (주)한화/기계           경기도 성남시 분당구 판교로 305  37.398551  127.106815
# 1826  (주)한화/기계        충청남도 아산시 둔포면 아산밸리로 312  36.913107  127.062119
# 1827  SK Hynix         경기도 이천시 부발읍 경충대로 2091  37.250125  127.483494
#
# [1828 rows x 4 columns]

# %%
rows2 = get_distances_with_df(df1=start_bucks_loc_select, df2=company_locations, df1_basis='지점명', df2_basis='기업명' )
# Out:
# <ipython-input-45-60d24b432f9c>:31: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   distance = geopy.distance.vincenty(coord1, coord2).km

# %%
one_star_comp_dist = pd.DataFrame(rows2)
one_star_comp_dist2 = one_star_comp_dist.groupby(['지점명','기업명'],as_index=False).min()
one_star_comp_dist2.sort_values('distance')
# Out:
#                   지점명         기업명      distance
# 81   스타벅스 리버사이드팔당DTR점     고려개발(주)      2.260956
# 461  스타벅스 리버사이드팔당DTR점     이화산업(주)      3.458007
# 457  스타벅스 리버사이드팔당DTR점        이스타코      4.173619
# 282  스타벅스 리버사이드팔당DTR점     삼성물산(주)      5.101365
# 286  스타벅스 리버사이드팔당DTR점  삼성엔지니어링(주)      5.109276
# ..                ...         ...           ...
# 253  스타벅스 리버사이드팔당DTR점      바다로19호    455.596002
# 492  스타벅스 리버사이드팔당DTR점        제주항공    457.013782
# 616  스타벅스 리버사이드팔당DTR점       한라(주)    464.286802
# 368  스타벅스 리버사이드팔당DTR점       신원(주)    480.180957
# 401  스타벅스 리버사이드팔당DTR점  에이프로젠제약(주)  13204.506641
#
# [710 rows x 3 columns]

# %%
pd.read_csv('star_company_distance.csv', sep='\t',index_col=0)
# Out:
#              지점명        기업명   distance
# 0      스타벅스 연희DT    대림통상(주)   0.038625
# 1     스타벅스 창원역DT       주연테크   0.048103
# 2      스타벅스 신림DT       모나리자   0.056810
# 3    스타벅스 인천송도DT  한국단자공업(주)   0.101525
# 4      스타벅스 천안IC        윌비스   0.108159
# ..           ...        ...        ...
# 664  스타벅스 제주성산DT    태영건설(주)  35.794713
# 665  스타벅스 전북정읍DT         한창  36.352651
# 666  스타벅스 충남보령DT       현대제철  40.347745
# 667    스타벅스 속초DT       강원랜드  54.958288
# 668    스타벅스 속초DT         대창  55.430599
#
# [669 rows x 3 columns]

# %%
x = pd.read_csv('/Users/dhkim/PycharmProjects/company_list/전국관광지정보표준데이터-20200702.csv',encoding='utf-8')
column_maps = {unnamed:col for unnamed, col in zip (x.columns, x.loc[0,:].values)}

# %%
# x = x.loc[1:,:].rename(columns=column_maps)
x.head()
# Out:
#       관광지명 관광지구분                  소재지도로명주소                 소재지지번주소  \
# 1    공룡박물관   관광지   전라남도 해남군 황산면 공룡박물관길 234    전라남도 해남군 황산면 우항리 191
# 2  아우라지관광지   관광지   강원도 정선군 여량면 여량리, 유천리 일원                     NaN
# 3    화암관광지   관광지  강원도 정선군 화암면 화암리 540번지 일원                     NaN
# 4   창평슬로시티   관광지    전라남도 담양군 창평면 돌담길 56-24  전라남도 담양군 창평면 창평리 113-1
# 5  한국가사문학관   관광지  전라남도 담양군 가사문학면 가사문학로 877  전라남도 담양군 가사문학면 지곡리 319
#
#               위도              경도      면적  \
# 1  34.5890888499      126.442833  332610
# 2      37.475854      128.724151  122244
# 3      37.350854      128.790064  213235
# 4  35.2352508415  127.0178937631   15680
# 5  35.1879635114  127.0054853524    2022
#
#                                             공공편익시설정보              숙박시설정보  \
# 1                                            휴게실, 매점                해당없음
# 2                      관리사무소(1동)+화장실(3동)+수변산책로+데크산책로                 NaN
# 3  관리사무소(3동)+오수처리장(2동)+화장실(6동)+주차장(3개소)+동굴관리소(2동)...                 NaN
# ...

# %%
trip_advisor_ = x[['관광지명', '위도', '경도', '면적', '수용인원수']]
trip_advisor = trip_advisor_.rename(columns={'위도':'latitude', '경도':'longitude'})
trip_advisor = trip_advisor.reset_index(drop=True)
trip_advisor
# Out:
#           관광지명       latitude       longitude       면적  수용인원수
# 0        공룡박물관  34.5890888499      126.442833   332610   3000
# 1      아우라지관광지      37.475854      128.724151   122244   1260
# 2        화암관광지      37.350854      128.790064   213235   3000
# 3       창평슬로시티  35.2352508415  127.0178937631    15680    470
# 4      한국가사문학관  35.1879635114  127.0054853524     2022    250
# ..         ...            ...             ...      ...    ...
# 431       구암서원  35.8988159169  128.5990001332    65000    500
# 432       함지공원     35.9424608      128.570482    44385  10000
# 433  경북대학교 캠퍼스  35.8890984884  128.6143216921  1317639  50000
# 434     금호강하중도      35.900092      128.559326   223000  50000
# 435    팔달대교 야경      35.895353      128.550766    10000   1000
#
# [436 rows x 5 columns]

# %%
start_bucks_dt
# Out:
#                지점명   latitude   longitude  SORT
# 0      스타벅스 울산신정DT  35.544170  129.324735  스타벅스
# 1     스타벅스 경주보문로DT  35.853218  129.268695  스타벅스
# 2       스타벅스 동수원DT  37.278015  127.033828  스타벅스
# 3       스타벅스 서귀포DT  33.249525  126.506710  스타벅스
# 4     스타벅스 구미금오산DT  36.122231  128.323599  스타벅스
# ..             ...        ...         ...   ...
# 249   스타벅스 목포터미널DT  34.810016  126.417053  스타벅스
# 250    스타벅스 마산회원DT  35.220657  128.574434  스타벅스
# 251     스타벅스 평촌역DT  37.396431  126.969419  스타벅스
# 252    스타벅스 시흥대야DT  37.443912  126.790755  스타벅스
# 253  스타벅스 수원경수인계DT  37.267928  127.027944  스타벅스
#
# [254 rows x 4 columns]

# %%
trip_rows = get_distances_with_df(df1=start_bucks_dt, df2=trip_advisor, df1_basis='지점명', df2_basis='관광지명' )
# Out:
# <ipython-input-245-17b22cb07c41>:31: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   distance = geopy.distance.vincenty(coord1, coord2).km

# %%
star_trip_distance = pd.DataFrame(trip_rows)
star_trip_distance
star_trip_distance = star_trip_distance.rename(columns={'loc_name':'지점명', 'loc_name2':'관광지명'})
star_trip_distance
# Out:
#                   지점명       관광지명    distance
# 0         스타벅스 울산신정DT      공룡박물관  283.406265
# 1         스타벅스 울산신정DT    아우라지관광지  221.002828
# 2         스타벅스 울산신정DT      화암관광지  206.132412
# 3         스타벅스 울산신정DT     창평슬로시티  212.362654
# 4         스타벅스 울산신정DT    한국가사문학관  214.440284
# ...               ...        ...         ...
# 110739  스타벅스 수원경수인계DT       구암서원  206.999148
# 110740  스타벅스 수원경수인계DT       함지공원  201.690224
# 110741  스타벅스 수원경수인계DT  경북대학교 캠퍼스  208.727880
# 110742  스타벅스 수원경수인계DT     금호강하중도  204.498566
# 110743  스타벅스 수원경수인계DT    팔달대교 야경  204.380357
#
# [110744 rows x 3 columns]

# %%
def find_mindist_starbucks(groupped_df, basis_name='star_name'):
    new_df = {}
#     groupped_df = groupped_df.reset_index(drop=True)
    groupped_df = groupped_df.sort_values(by='distance').reset_index(drop=True)
    new_df['distance'] = groupped_df.loc[:2]['distance']
    new_df[basis_name] = groupped_df.loc[:2][basis_name]

    return pd.Series(new_df, index=[basis_name, 'distance'])

star_trip_distance2 = star_trip_distance.groupby(['지점명']).apply(lambda x:find_mindist_starbucks(x,'관광지명'))
star_trip_distance2 = star_trip_distance2.reset_index()
# star_trip_distance2.to_csv('star_trip_distance.csv', sep='\t')
star_trip_distance2
# Out:
#                지점명                                               관광지명  \
# 0      스타벅스 강동구청DT  0        이성산성
# 1    고구려대장간마을
# 2        광주향교
# Name...
# 1      스타벅스 강동암사DT  0    고구려대장간마을
# 1        이성산성
# 2        광주향교
# Name...
# 2      스타벅스 강릉송정DT  0         망상
# 1       무릉계곡
# 2    아우라지관광지
# Name: 관...
# 3      스타벅스 거제대로DT  0    포로수용소유적공원
# 1        거제박물관
# 2        문동휴양지
# N...
# 4    스타벅스 경기광주송정DT  0       중대물빛공원
# 1    경안천습지생태공원
# 2      경기도자박물관
# N...
# ..             ...                                                ...
# 249     스타벅스 풍무역DT  0        김포 장릉
# 1    현대프리미엄아울렛
# 2    아라뱃길김포터미널
# N...
# 250    스타벅스 하남미사DT  0    유니온파크
# 1     이성산성
# 2     광주향교
# Name: 관광지명, d...
# 251  스타벅스 해운대달맞이DT  0    해운대해수욕장
# 1    달맞이동산지구
# 2        동백섬
# Name: 관...
# 252      스타벅스 화곡DT  0    허준근린공원
# 1      허가바위
# 2      양천향교
# Name: 관광지명...
# 253    스타벅스 화성병점DT  0          중대물빛공원
# 1             헌인릉
# 2    매헌 윤봉...
#
#                                               distance
# ...

# %%
star_trip_distance2.loc[0]['distance'].values
# star_company_distance2['distance'].values[0]

star_trip_distance3 = pd.DataFrame({'지점명':np.repeat(star_trip_distance2.지점명.values, star_trip_distance2.관광지명.str.len()),
                        '관광지명':np.concatenate(star_trip_distance2.관광지명.values),'distance:':np.concatenate(star_trip_distance2.distance.values)})
star_trip_distance3
# Out:
#              지점명          관광지명  distance:
# 0    스타벅스 강동구청DT          이성산성   5.441880
# 1    스타벅스 강동구청DT      고구려대장간마을   5.978331
# 2    스타벅스 강동구청DT          광주향교   6.642934
# 3    스타벅스 강동암사DT      고구려대장간마을   3.241861
# 4    스타벅스 강동암사DT          이성산성   5.892129
# ..           ...           ...        ...
# 757    스타벅스 화곡DT          허가바위   4.021010
# 758    스타벅스 화곡DT          양천향교   4.664128
# 759  스타벅스 화성병점DT        중대물빛공원  25.705760
# 760  스타벅스 화성병점DT           헌인릉  28.219865
# 761  스타벅스 화성병점DT  매헌 윤봉길의사 기념관  28.815553
#
# [762 rows x 3 columns]

# %%
star_trip_distance4 = star_trip_distance3.groupby(['지점명', '관광지명'],as_index=False).min()
star_trip_distance4 = star_trip_distance4.rename(columns={'distance:':'distance'})
star_trip_distance4 = star_trip_distance4.sort_values('distance').reset_index(drop=True)
star_trip_distance4.to_csv('star_trip_distance.csv', sep='\t')
star_trip_distance4
# Out:
#                지점명     관광지명   distance
# 0      스타벅스 제주중문DT    천제연폭포   0.349134
# 1      스타벅스 온천장역DT      허심청   0.470208
# 2      스타벅스 동래미남DT   우장춘기념관   0.699527
# 3     스타벅스 부산교대역DT   우장춘기념관   0.699527
# 4       스타벅스 낙성대DT   강감찬전시관   0.705601
# ..             ...      ...        ...
# 757  스타벅스 경주보문호수DT      작괘천  37.251925
# 758   스타벅스 경주보문로DT      작괘천  37.251925
# 759    스타벅스 포항장성DT  주왕산 관광지  41.819833
# 760    스타벅스 포항죽도DT  주왕산 관광지  45.422089
# 761    스타벅스 포항쌍용DT  주왕산 관광지  45.858396
#
# [762 rows x 3 columns]

# %%
star_trip_distance4[star_trip_distance4['distance']<2]
# Out:
#               지점명         관광지명  distance
# 0     스타벅스 제주중문DT        천제연폭포  0.349134
# 1     스타벅스 온천장역DT          허심청  0.470208
# 2     스타벅스 동래미남DT       우장춘기념관  0.699527
# 3    스타벅스 부산교대역DT       우장춘기념관  0.699527
# 4      스타벅스 낙성대DT       강감찬전시관  0.705601
# 5      스타벅스 낙성대DT     미당서정주의 집  0.799259
# 6       스타벅스 밀양DT        밀양영남루  0.819831
# 7   스타벅스 마산해안대로DT    마산해양레포츠센터  0.858530
# 8     스타벅스 대구침산DT        꽃보라동산  0.864522
# 9     스타벅스 인천동춘DT        가천박물관  0.876858
# 10     스타벅스 남양산IC         양산타워  0.918377
# 11    스타벅스 대전대사DT        아쿠아리움  0.928318
# 12   스타벅스 풍무사거리DT        김포 장릉  0.950700
# 13    스타벅스 계룡대로DT    이심원충신정려현판  0.965536
# 14    스타벅스 군산나운DT        은파관광지  1.004226
# 15    스타벅스 온천장역DT     해양자연사박물관  1.018836
# 16  스타벅스 해운대달맞이DT      해운대해수욕장  1.033886
# 17      스타벅스 밀양DT         밀양관아  1.057865
# 18    스타벅스 부산안락DT          충렬사  1.080417
# 19    스타벅스 온천장역DT         금강공원  1.095149
# 20  스타벅스 해운대달맞이DT      달맞이동산지구  1.116208
# 21    스타벅스 인천송도DT      컴팩스마트시티  1.164329
# ...
